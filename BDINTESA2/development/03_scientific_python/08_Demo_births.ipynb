# %% [markdown]
# ## Analysis of the baby names dataset

# %%
import pandas as pd
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
names = pd.read_csv('dataset/baby-names.csv')

# %%
names.head()
# Out:
#    year     name      prop  sex soundex
# 0  1880     John  0.081541  boy    J500
# 1  1880  William  0.080511  boy    W450
# 2  1880    James  0.050057  boy    J520
# 3  1880  Charles  0.045167  boy    C642
# 4  1880   George  0.043292  boy    G620

# %%
names.dtypes
# Out:
# year         int64
# name        object
# prop       float64
# sex         object
# soundex     object
# dtype: object

# %%
names[names['year'] == 1889]
# Out:
#         year        name      prop   sex soundex
# 9000    1889        John  0.071804   boy    J500
# 9001    1889     William  0.065286   boy    W450
# 9002    1889       James  0.042185   boy    J520
# 9003    1889      George  0.037213   boy    G620
# 9004    1889     Charles  0.035272   boy    C642
# 9005    1889       Frank  0.024990   boy    F652
# 9006    1889      Joseph  0.022924   boy    J210
# 9007    1889       Harry  0.021496   boy    H600
# 9008    1889      Robert  0.021118   boy    R163
# 9009    1889      Edward  0.019312   boy    E363
# 9010    1889       Henry  0.019203   boy    H560
# 9011    1889      Thomas  0.018757   boy    T520
# 9012    1889      Walter  0.016095   boy    W436
# 9013    1889      Arthur  0.014011   boy    A636
# 9014    1889        Fred  0.013054   boy    F630
# 9015    1889      Albert  0.011365   boy    A416
# 9016    1889    Clarence  0.008266   boy    C465
# 9017    1889         Roy  0.007459   boy    R000
# ...

# %%
names[names.year == 1880].tail()
# Out:
#         year     name      prop   sex soundex
# 129995  1880  Emaline  0.000041  girl    E545
# 129996  1880    Ester  0.000041  girl    E236
# 129997  1880    Eulah  0.000041  girl    E400
# 129998  1880  Eulalie  0.000041  girl    E440
# 129999  1880     Euna  0.000041  girl    E500

# %%
boys = names[names.sex == 'boy']    # segment the data into boy and girl names. We have 2 dataframes now.
girls = names[names.sex == 'girl']

# %%
boys.groupby('year')

# %%
boys.groupby('year').size()
# Out:
# year
# 1880    1000
# 1881    1000
# 1882    1000
# 1883    1000
# 1884    1000
# 1885    1000
# 1886    1000
# 1887    1000
# 1888    1000
# 1889    1000
# 1890    1000
# 1891    1000
# 1892    1000
# 1893    1000
# 1894    1000
# 1895    1000
# 1896    1000
# 1897    1000
# 1898    1000
# 1899    1000
# 1900    1000
# 1901    1000
# 1902    1000
# 1903    1000
# 1904    1000
# 1905    1000
# 1906    1000
# 1907    1000
# 1908    1000
# 1909    1000
#         ...
# 1979    1000
# 1980    1000
# 1981    1000
# 1982    1000
# 1983    1000
# 1984    1000
# 1985    1000
# 1986    1000
# 1987    1000
# 1988    1000
# 1989    1000
# 1990    1000
# 1991    1000
# 1992    1000
# 1993    1000
# 1994    1000
# 1995    1000
# 1996    1000
# 1997    1000
# 1998    1000
# 1999    1000
# 2000    1000
# 2001    1000
# 2002    1000
# 2003    1000
# 2004    1000
# 2005    1000
# 2006    1000
# 2007    1000
# 2008    1000
# Length: 129, dtype: int64

# %%
names.groupby(['year', 'sex']).size()
# Out:
# year  sex
# 1880  boy     1000
#       girl    1000
# 1881  boy     1000
#       girl    1000
# 1882  boy     1000
#       girl    1000
# 1883  boy     1000
#       girl    1000
# 1884  boy     1000
#       girl    1000
# 1885  boy     1000
#       girl    1000
# 1886  boy     1000
#       girl    1000
# 1887  boy     1000
#       girl    1000
# 1888  boy     1000
#       girl    1000
# 1889  boy     1000
#       girl    1000
# 1890  boy     1000
#       girl    1000
# 1891  boy     1000
#       girl    1000
# 1892  boy     1000
#       girl    1000
# 1893  boy     1000
#       girl    1000
# 1894  boy     1000
#       girl    1000
#               ...
# 1994  boy     1000
#       girl    1000
# 1995  boy     1000
#       girl    1000
# 1996  boy     1000
#       girl    1000
# 1997  boy     1000
#       girl    1000
# 1998  boy     1000
#       girl    1000
# 1999  boy     1000
#       girl    1000
# 2000  boy     1000
#       girl    1000
# 2001  boy     1000
#       girl    1000
# ...

# %%
names.groupby(['year', 'sex']).head()
# Out:
#         year      name      prop   sex soundex
# 0       1880      John  0.081541   boy    J500
# 1       1880   William  0.080511   boy    W450
# 2       1880     James  0.050057   boy    J520
# 3       1880   Charles  0.045167   boy    C642
# 4       1880    George  0.043292   boy    G620
# 1000    1881      John  0.080975   boy    J500
# 1001    1881   William  0.078712   boy    W450
# 1002    1881     James  0.050253   boy    J520
# 1003    1881    George  0.043068   boy    G620
# 1004    1881   Charles  0.042828   boy    C642
# 2000    1882      John  0.078314   boy    J500
# 2001    1882   William  0.076191   boy    W450
# 2002    1882     James  0.048281   boy    J520
# 2003    1882    George  0.042553   boy    G620
# 2004    1882   Charles  0.041726   boy    C642
# 3000    1883      John  0.079066   boy    J500
# 3001    1883   William  0.074558   boy    W450
# 3002    1883     James  0.046449   boy    J520
# 3003    1883   Charles  0.042911   boy    C642
# ...

# %%
names.groupby(['year', 'sex']).size().loc[2000] # year 2000
# Out:
# sex
# boy     1000
# girl    1000
# dtype: int64

# %%
boys[boys.year == 2000]   # We would like to find out most popular boy names for each year.
# Out:
#         year         name      prop  sex soundex
# 120000  2000        Jacob  0.016514  boy    J210
# 120001  2000      Michael  0.015346  boy    M240
# 120002  2000      Matthew  0.013695  boy    M300
# 120003  2000       Joshua  0.013194  boy    J200
# 120004  2000  Christopher  0.011990  boy    C623
# 120005  2000     Nicholas  0.011815  boy    N242
# 120006  2000       Andrew  0.011324  boy    A536
# 120007  2000       Joseph  0.010930  boy    J210
# 120008  2000       Daniel  0.010681  boy    D540
# 120009  2000        Tyler  0.010305  boy    T460
# 120010  2000      William  0.009896  boy    W450
# 120011  2000      Brandon  0.009745  boy    B653
# 120012  2000         Ryan  0.009715  boy    R500
# 120013  2000         John  0.009617  boy    J500
# 120014  2000      Zachary  0.009516  boy    Z260
# 120015  2000        David  0.009454  boy    D130
# 120016  2000      Anthony  0.009416  boy    A535
# 120017  2000        James  0.008613  boy    J520
# ...

# %%
boys[boys.year == 2000]['prop']
# Out:
# 120000    0.016514
# 120001    0.015346
# 120002    0.013695
# 120003    0.013194
# 120004    0.011990
# 120005    0.011815
# 120006    0.011324
# 120007    0.010930
# 120008    0.010681
# 120009    0.010305
# 120010    0.009896
# 120011    0.009745
# 120012    0.009715
# 120013    0.009617
# 120014    0.009516
# 120015    0.009454
# 120016    0.009416
# 120017    0.008613
# 120018    0.008520
# 120019    0.008282
# 120020    0.008085
# 120021    0.007693
# 120022    0.007643
# 120023    0.007378
# 120024    0.007298
# 120025    0.007108
# 120026    0.006836
# 120027    0.006780
# 120028    0.006577
# 120029    0.006241
#             ...
# 120970    0.000074
# 120971    0.000074
# 120972    0.000074
# 120973    0.000073
# 120974    0.000073
# 120975    0.000073
# 120976    0.000073
# 120977    0.000073
# 120978    0.000073
# 120979    0.000072
# 120980    0.000072
# 120981    0.000072
# 120982    0.000072
# 120983    0.000072
# 120984    0.000072
# 120985    0.000072
# ...

# %%
boys[boys.year == 2000][:5]
# Out:
#         year         name      prop  sex soundex
# 120000  2000        Jacob  0.016514  boy    J210
# 120001  2000      Michael  0.015346  boy    M240
# 120002  2000      Matthew  0.013695  boy    M300
# 120003  2000       Joshua  0.013194  boy    J200
# 120004  2000  Christopher  0.011990  boy    C623

# %%
boys[boys.year == 2000]['prop'].idxmax()
# Out:
# 120000

# %%
boys.loc[boys[boys.year == 2000]['prop'].idxmax()]  # to get the whole row.
# Out:
# year           2000
# name          Jacob
# prop       0.016514
# sex             boy
# soundex        J210
# Name: 120000, dtype: object

# %%
# Using function
def get_max_record(group):
    return group.loc[group['prop'].idxmax()]

get_max_record(boys)
# Out:
# year           1880
# name           John
# prop       0.081541
# sex             boy
# soundex        J500
# Name: 0, dtype: object

# %%
def get_max_record(group):
    return group.loc[group['prop'].idxmax()]

result = boys.groupby('year').apply(get_max_record)

# %%
result
# Out:
#       year     name      prop  sex soundex
# year
# 1880  1880     John  0.081541  boy    J500
# 1881  1881     John  0.080975  boy    J500
# 1882  1882     John  0.078314  boy    J500
# 1883  1883     John  0.079066  boy    J500
# 1884  1884     John  0.076476  boy    J500
# 1885  1885     John  0.075517  boy    J500
# 1886  1886     John  0.075820  boy    J500
# 1887  1887     John  0.074181  boy    J500
# 1888  1888     John  0.071186  boy    J500
# 1889  1889     John  0.071804  boy    J500
# 1890  1890     John  0.071034  boy    J500
# 1891  1891     John  0.070292  boy    J500
# 1892  1892     John  0.068759  boy    J500
# 1893  1893     John  0.066495  boy    J500
# 1894  1894     John  0.065961  boy    J500
# 1895  1895     John  0.065699  boy    J500
# 1896  1896     John  0.063051  boy    J500
# 1897  1897     John  0.061907  boy    J500
# 1898  1898     John  0.061770  boy    J500
# 1899  1899     John  0.060674  boy    J500
# 1900  1900     John  0.060619  boy    J500
# ...

# %%
result['prop'].plot()

# %%
boys[boys.name == 'Travis']
# Out:
#         year    name      prop  sex soundex
# 563     1880  Travis  0.000101  boy    T612
# 2648    1882  Travis  0.000082  boy    T612
# 3672    1883  Travis  0.000080  boy    T612
# 4656    1884  Travis  0.000081  boy    T612
# 5602    1885  Travis  0.000095  boy    T612
# 6598    1886  Travis  0.000092  boy    T612
# 9871    1889  Travis  0.000059  boy    T612
# 10733   1890  Travis  0.000075  boy    T612
# 11696   1891  Travis  0.000082  boy    T612
# 12593   1892  Travis  0.000099  boy    T612
# 13831   1893  Travis  0.000066  boy    T612
# 14849   1894  Travis  0.000064  boy    T612
# 15735   1895  Travis  0.000079  boy    T612
# 16774   1896  Travis  0.000077  boy    T612
# 17645   1897  Travis  0.000098  boy    T612
# 18991   1898  Travis  0.000053  boy    T612
# 19658   1899  Travis  0.000095  boy    T612
# 20442   1900  Travis  0.000166  boy    T612
# 22552   1902  Travis  0.000121  boy    T612
# 23778   1903  Travis  0.000077  boy    T612
# ...

# %%
idf = boys.set_index(['name', 'year'])

# %%
idf[-50:]
# Out:
#                     prop  sex soundex
# name      year
# Reilly    2008  0.000097  boy    R400
# Sheldon   2008  0.000097  boy    S435
# Abdullah  2008  0.000097  boy    A134
# Jagger    2008  0.000097  boy    J260
# Thaddeus  2008  0.000097  boy    T320
# Case      2008  0.000096  boy    C200
# Kyson     2008  0.000096  boy    K250
# Lamont    2008  0.000096  boy    L553
# Chaz      2008  0.000096  boy    C200
# Makhi     2008  0.000096  boy    M200
# Jan       2008  0.000095  boy    J500
# Marques   2008  0.000095  boy    M622
# Oswaldo   2008  0.000095  boy    O243
# Donavan   2008  0.000095  boy    D515
# Keyon     2008  0.000095  boy    K500
# Kyan      2008  0.000095  boy    K500
# Simeon    2008  0.000095  boy    S550
# Trystan   2008  0.000095  boy    T623
# Andreas   2008  0.000094  boy    A536
# Dangelo   2008  0.000094  boy    D524
# Landin    2008  0.000094  boy    L535
# Reagan    2008  0.000094  boy    R250
# Turner    2008  0.000094  boy    T656
# ...

# %%
idf.loc['Travis']
# Out:
#           prop  sex soundex
# year
# 1880  0.000101  boy    T612
# 1882  0.000082  boy    T612
# 1883  0.000080  boy    T612
# 1884  0.000081  boy    T612
# 1885  0.000095  boy    T612
# 1886  0.000092  boy    T612
# 1889  0.000059  boy    T612
# 1890  0.000075  boy    T612
# 1891  0.000082  boy    T612
# 1892  0.000099  boy    T612
# 1893  0.000066  boy    T612
# 1894  0.000064  boy    T612
# 1895  0.000079  boy    T612
# 1896  0.000077  boy    T612
# 1897  0.000098  boy    T612
# 1898  0.000053  boy    T612
# 1899  0.000095  boy    T612
# 1900  0.000166  boy    T612
# 1902  0.000121  boy    T612
# 1903  0.000077  boy    T612
# 1904  0.000137  boy    T612
# 1905  0.000147  boy    T612
# 1906  0.000118  boy    T612
# 1907  0.000132  boy    T612
# 1908  0.000150  boy    T612
# 1909  0.000181  boy    T612
# 1910  0.000149  boy    T612
# 1911  0.000166  boy    T612
# 1912  0.000171  boy    T612
# 1913  0.000203  boy    T612
# ...        ...  ...     ...
# 1979  0.006169  boy    T612
# ...

# %%
idf.loc['Travis']['prop'].plot()

# %%
boys.groupby('name')['prop'].mean()
# Out:
# name
# Aaden        0.000442
# Aarav        0.000101
# Aaron        0.002266
# Ab           0.000044
# Abb          0.000046
# Abbie        0.000046
# Abbott       0.000044
# Abdiel       0.000092
# Abdul        0.000064
# Abdullah     0.000094
# Abe          0.000225
# Abel         0.000152
# Abelardo     0.000041
# Abie         0.000042
# Abner        0.000130
# Abraham      0.000494
# Abram        0.000105
# Ace          0.000080
# Acey         0.000042
# Acie         0.000062
# Acy          0.000046
# Ada          0.000057
# Adalberto    0.000051
# Adam         0.002242
# Adams        0.000053
# Adan         0.000131
# Add          0.000043
# Addie        0.000065
# Addison      0.000114
# Adelard      0.000065
#                ...
# Yoshio       0.000054
# Young        0.000080
# Yurem        0.000091
# Yusuf        0.000096
# Zachariah    0.000275
# Zachary      0.003748
# Zachery      0.000369
# Zack         0.000113
# Zackary      0.000373
# Zackery      0.000232
# ...

# %%
boys.groupby('name')['prop'].mean().sort_values()
# Out:
# name
# Kennard        0.000027
# Danniel        0.000027
# Deryl          0.000028
# Grayling       0.000028
# Michial        0.000028
# Cheryl         0.000028
# Dwyane         0.000028
# Levern         0.000029
# Theodis        0.000029
# Randolf        0.000029
# Diane          0.000029
# Renard         0.000029
# Kimball        0.000029
# Patric         0.000029
# Lex            0.000030
# Dann           0.000030
# Erasmo         0.000030
# Darryll        0.000030
# Garey          0.000030
# Rudolfo        0.000030
# Michal         0.000031
# Lyn            0.000031
# Brenda         0.000031
# Mikeal         0.000031
# Desi           0.000031
# Kem            0.000031
# Kathleen       0.000031
# Terance        0.000031
# Cynthia        0.000031
# Linden         0.000031
#                  ...
# Arthur         0.005845
# Brandon        0.005951
# Andrew         0.006088
# Harry          0.006162
# Matthew        0.006178
# Anthony        0.006315
# Kenneth        0.006470
# ...

# %%
boys['prop'].describe()   # Getting the summary of statistics from the dataframe, based on proportion.
# Out:
# count    129000.000000
# mean          0.000916
# std           0.003441
# min           0.000026
# 25%           0.000071
# 50%           0.000142
# 75%           0.000453
# max           0.081541
# Name: prop, dtype: float64

# %%
result = boys.groupby('year')['prop'].describe()
result[:50]
# Out:
#        count      mean       std       min       25%       50%       75%  \
# year
# 1880  1000.0  0.000931  0.004871  0.000042  0.000059  0.000118  0.000372
# 1881  1000.0  0.000930  0.004812  0.000037  0.000065  0.000120  0.000369
# 1882  1000.0  0.000928  0.004691  0.000041  0.000066  0.000115  0.000377
# 1883  1000.0  0.000929  0.004675  0.000044  0.000062  0.000116  0.000382
# 1884  1000.0  0.000927  0.004542  0.000041  0.000065  0.000122  0.000385
# 1885  1000.0  0.000926  0.004459  0.000043  0.000069  0.000121  0.000373
# 1886  1000.0  0.000926  0.004447  0.000042  0.000067  0.000118  0.000397
# 1887  1000.0  0.000925  0.004380  0.000046  0.000073  0.000119  0.000366
# 1888  1000.0  0.000923  0.004294  0.000046  0.000069  0.000123  0.000379
# 1889  1000.0  0.000924  0.004260  0.000042  0.000067  0.000118  0.000355
# 1890  1000.0  0.000921  0.004191  0.000042  0.000067  0.000125  0.000384
# 1891  1000.0  0.000920  0.004126  0.000046  0.000073  0.000119  0.000368
# ...

# %%
df = boys[boys.year == 2008]
df['prop']
# Out:
# 128000    0.010355
# 128001    0.009437
# 128002    0.009301
# 128003    0.008799
# 128004    0.008702
# 128005    0.008566
# 128006    0.008442
# 128007    0.008438
# 128008    0.008268
# 128009    0.008061
# 128010    0.007877
# 128011    0.007694
# 128012    0.007570
# 128013    0.007467
# 128014    0.007262
# 128015    0.007165
# 128016    0.006952
# 128017    0.006754
# 128018    0.006372
# 128019    0.006102
# 128020    0.006085
# 128021    0.006042
# 128022    0.005985
# 128023    0.005974
# 128024    0.005930
# 128025    0.005905
# 128026    0.005838
# 128027    0.005829
# 128028    0.005752
# 128029    0.005414
#             ...
# 128970    0.000094
# 128971    0.000094
# 128972    0.000094
# 128973    0.000094
# 128974    0.000094
# 128975    0.000094
# 128976    0.000094
# 128977    0.000093
# 128978    0.000093
# 128979    0.000093
# 128980    0.000093
# 128981    0.000093
# 128982    0.000093
# 128983    0.000092
# 128984    0.000092
# 128985    0.000092
# ...

# %%
def get_quantile_count(group, quantile = 0.5):
    df = group.sort_values(by='prop', ascending=False)
    return df['prop'].values.cumsum().searchsorted(quantile)

boys.groupby('year').apply(get_quantile_count).plot()

# %%
def get_quantile_count(group, quantile=0.5):
    group = group.groupby('soundex').sum()
    df = group.sort_values(by='prop', ascending=False)
    return df['prop'].values.cumsum().searchsorted(quantile)

q = 0.25
boy_ct = boys.groupby('year').apply(get_quantile_count, quantile=q)   # pass different values for quantile
girl_ct = girls.groupby('year').apply(get_quantile_count, quantile=q)
boy_ct.plot(label='boy')
girl_ct.plot(label='girl')
legend(loc='best')

# %% [markdown]
# ## Merge with other Dataset

# %%
births = pd.read_csv('dataset/births.csv')
births.head()
# Out:
#    year  sex  births
# 0  1880  boy  118405
# 1  1881  boy  108290
# 2  1882  boy  122034
# 3  1883  boy  112487
# 4  1884  boy  122745

# %%
merged = pd.merge(names, births, on=['year', 'sex'])   # merge 2 tables: names and births.
merged.head()
# Out:
#    year     name      prop  sex soundex  births
# 0  1880     John  0.081541  boy    J500  118405
# 1  1880  William  0.080511  boy    W450  118405
# 2  1880    James  0.050057  boy    J520  118405
# 3  1880  Charles  0.045167  boy    C642  118405
# 4  1880   George  0.043292  boy    G620  118405

# %%
merged['persons'] = np.floor(merged.prop * merged.births)

# %%
merged.head()
# Out:
#    year     name      prop  sex soundex  births  persons
# 0  1880     John  0.081541  boy    J500  118405   9654.0
# 1  1880  William  0.080511  boy    W450  118405   9532.0
# 2  1880    James  0.050057  boy    J520  118405   5926.0
# 3  1880  Charles  0.045167  boy    C642  118405   5347.0
# 4  1880   George  0.043292  boy    G620  118405   5125.0

# %%
merged.groupby(['name', 'sex'])['persons'].sum()
# Out:
# name      sex
# Aaden     boy        959.0
# Aaliyah   girl     39660.0
# Aarav     boy        219.0
# Aaron     boy     508034.0
#           girl      1365.0
# Ab        boy         24.0
# Abagail   girl      2680.0
# Abb       boy         15.0
# Abbey     girl     14333.0
# Abbie     boy         10.0
#           girl     16556.0
# Abbigail  girl      6792.0
# Abbott    boy          9.0
# Abby      girl     47845.0
# Abdiel    boy        199.0
# Abdul     boy       2609.0
# Abdullah  boy       2352.0
# Abe       boy       6835.0
# Abel      boy      30752.0
# Abelardo  boy         68.0
# Abie      boy          4.0
# Abigail   girl    240993.0
# Abigale   girl      2429.0
# Abigayle  girl      3510.0
# Abner     boy       2304.0
# Abraham   boy      68620.0
# Abram     boy       8148.0
# Abril     girl      3660.0
# Ace       boy        935.0
# Acey      boy          4.0
#                     ...
# Zelda     girl     10001.0
# Zelia     girl        77.0
# Zella     girl      9951.0
# ...

# %%
merged.groupby(['name', 'sex'])['persons'].sum().sort_values()
# Out:
# name         sex
# Alabama      girl          3.0
# Daisye       girl          3.0
# Crissie      girl          3.0
# Dollye       girl          3.0
# Dema         girl          3.0
# Chestina     girl          3.0
# Ala          girl          3.0
# Clem         girl          3.0
# Chester      girl          3.0
# Eithel       girl          3.0
# Amey         girl          3.0
# Achsah       girl          3.0
# Alfred       girl          3.0
# Esequiel     boy           4.0
# Amil         boy           4.0
# Francina     girl          4.0
# Lovisa       girl          4.0
# Nolie        girl          4.0
# Hunt         boy           4.0
# Claiborne    boy           4.0
# Cilla        girl          4.0
# Lovie        boy           4.0
# Primus       boy           4.0
# Prosper      boy           4.0
# Hays         boy           4.0
# Lucina       girl          4.0
# Grove        boy           4.0
# Calhoun      boy           4.0
# Pryor        boy           4.0
# ...

# %%
mboys = pd.merge(boys, births) 
mboys.head()
# Out:
#    year     name      prop  sex soundex  births
# 0  1880     John  0.081541  boy    J500  118405
# 1  1880  William  0.080511  boy    W450  118405
# 2  1880    James  0.050057  boy    J520  118405
# 3  1880  Charles  0.045167  boy    C642  118405
# 4  1880   George  0.043292  boy    G620  118405

# %%
mboys['persons'] = np.floor(mboys.prop * mboys.births)
mboys.head()
# Out:
#    year     name      prop  sex soundex  births  persons
# 0  1880     John  0.081541  boy    J500  118405   9654.0
# 1  1880  William  0.080511  boy    W450  118405   9532.0
# 2  1880    James  0.050057  boy    J520  118405   5926.0
# 3  1880  Charles  0.045167  boy    C642  118405   5347.0
# 4  1880   George  0.043292  boy    G620  118405   5125.0

# %%
persons = mboys.set_index(['year', 'name'])['persons']

# %%
type(persons)
# Out:
# pandas.core.series.Series

# %%
persons
# Out:
# year  name
# 1880  John         9654.0
#       William      9532.0
#       James        5926.0
#       Charles      5347.0
#       George       5125.0
#       Frank        3241.0
#       Joseph       2632.0
#       Thomas       2533.0
#       Henry        2443.0
#       Robert       2415.0
#       Edward       2363.0
#       Harry        2152.0
#       Walter       1754.0
#       Arthur       1598.0
#       Fred         1568.0
#       Albert       1492.0
#       Samuel       1023.0
#       David         868.0
#       Louis         828.0
#       Joe           731.0
#       Charlie       729.0
#       Clarence      729.0
#       Richard       727.0
#       Andrew        644.0
#       Daniel        642.0
#       Ernest        614.0
#       Will          587.0
#       Jesse         568.0
#       Oscar         543.0
#       Lewis         516.0
#                     ...
# 2008  Landin        203.0
#       Reagan        203.0
#       Turner        203.0
#       Arnav         203.0
# ...

# %%
# Select out all the people named Chris. 
# Plot is kind of crowded. Matplotlib doesn't go more than 130 in x axis.
persons.loc[:, 'John'].plot(kind='bar', rot=90)

# %%
persons.loc[:, 'Alex'].plot(kind='bar', rot=90)

# %%
persons_after_1990 = persons.loc[1990:]

# %%
alex = persons_after_1990[:, 'Alex']

# %%
alex.plot(kind='line', rot=90)

# %%
alex.plot(kind='bar', rot=90)
