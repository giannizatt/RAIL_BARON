# %% [markdown]
# # Statistical Analysis
# ### Exercises (Statistical Significance)

# %%
# %pylab inline

import pandas as pd
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ## Analysis of the Mortality dataset
#
# This dataset is a sample extracted from the Centers for Disease Control and Prevention website.
# It was processed to include the description of cause of death.
#
# The complete dataset can be downloaded from ftp://ftp.cdc.gov/pub/Health_Statistics/NCHS/Datasets/DVS/mortality/mort2006us.zip

# %%
mort06 = pd.read_csv('dataset/mort06.smpl.csv.gz', compression='gzip')

# %%
mort06.head()
# Out:
#    Unnamed: 0  ResidentStatus  Education1989  Education2003  EducationFlag  \
# 0      257494               1            NaN            3.0              1
# 1     2388019               2            NaN            3.0              1
# 2      825566               1            8.0            NaN              0
# 3     1940408               1            NaN            3.0              1
# 4     1646521               1           12.0            NaN              0
#
#    MonthOfDeath Sex  AgeDetail  AgeSubstitution  AgeRecode52      ...        \
# 0             6   F       1088              NaN           43      ...
# 1             3   M       1069              NaN           39      ...
# 2             8   F       1083              NaN           42      ...
# 3             8   M       1063              NaN           38      ...
# 4             5   M       1084              NaN           42      ...
#
#    CauseRecord39   Race  BridgeRaceFlag  RaceImputationFlag RaceRecode3  \
# ...

# %%
mort06[['Sex', 'age', 'Cause']].head()
# Out:
#   Sex   age          Cause
# 0   F  88.0         Cancer
# 1   M  69.0          Other
# 2   F  83.0  Heart Disease
# 3   M  63.0          Other
# 4   M  84.0  Heart Disease

# %%
mort06['age'].describe()
# Out:
# count    243044.000000
# mean         72.292231
# std          19.006158
# min           0.000000
# 25%          63.000000
# 50%          77.000000
# 75%          86.000000
# max         112.000000
# Name: age, dtype: float64

# %%
mort06.groupby(['Cause'])['age'].describe()
# Out:
#                                 count       mean        std   min   25%   50%  \
# Cause
# Accidents                     12363.0  50.878994  24.591178   0.0  31.0  48.0
# Alzheimer's Disease            7336.0  86.065567   7.487226  40.0  82.0  87.0
# Cancer                        57162.0  70.236276  14.180137   0.0  61.0  72.0
# Chronic respiratory diseases  12386.0  76.369369  11.709776   0.0  70.0  78.0
# Diabetes                       7271.0  72.426489  14.291100   0.0  63.0  75.0
# Heart Disease                 82593.0  77.663361  14.378465   0.0  70.0  81.0
# Homicide                       1917.0  32.189880  15.470102   0.0  22.0  28.0
# Influenza and pheumonia        5826.0  80.155338  15.531745   0.0  76.0  84.0
# Other                         52956.0  70.437080  23.609807   0.0  60.0  78.0
# Suicide                        3234.0  46.141002  17.994120   8.0  32.0  45.0
#
#                                75%    max
# Cause
# Accidents                     73.0  108.0
# ...

# %%
mort06.boxplot('age', by=['Cause', 'Sex'], figsize=(15,8))
xticks(rotation=90);
# Out:
# /Users/alexcomu/Desktop/WORK/BIGDIVE/BDINTESA2/env/lib/python2.7/site-packages/numpy/core/fromnumeric.py:57: FutureWarning: reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead
#   return getattr(obj, method)(*args, **kwds)
