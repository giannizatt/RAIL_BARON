# %%
import pandas as pd
speedtest = pd.read_csv('../dataset/speedtest.csv')

# %% [markdown]
# # Mean download / upload velocity per ISP FASTWEB
#
# ### Select Fastweb Only

# %%
mask = speedtest['ISP']=='Fastweb'
df = speedtest[mask]

# %% [markdown]
# ### First of all we need to clean the dataset and fill/drop empty values

# %%
# Remove unused columns
df = df.drop('ISP', axis=1)
df = df.drop('CLIENT_REGION', axis=1)
df = df.drop('CLIENT_IP', axis=1)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 45581 entries, 9 to 199143
# Data columns (total 12 columns):
# CLIENT_CITY                45483 non-null object
# CLIENT_COUNTRY             45581 non-null object
# CLIENT_LATITUDE            45581 non-null float64
# CLIENT_LONGITUDE           45581 non-null float64
# TEST_DATE                  45581 non-null object
# SERVER_NAME                45581 non-null object
# DOWNLOAD_KBPS              45581 non-null int64
# UPLOAD_KBPS                45581 non-null int64
# LATENCY                    45581 non-null int64
# CLIENT_BROWSER             45581 non-null object
# CLIENT_OPERATING_SYSTEM    45581 non-null object
# USER_AGENT                 45581 non-null object
# dtypes: float64(2), int64(3), object(7)
# memory usage: 4.5+ MB

# %%
df['CLIENT_CITY'].fillna('Not Provided', inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 45581 entries, 9 to 199143
# Data columns (total 12 columns):
# CLIENT_CITY                45581 non-null object
# CLIENT_COUNTRY             45581 non-null object
# CLIENT_LATITUDE            45581 non-null float64
# CLIENT_LONGITUDE           45581 non-null float64
# TEST_DATE                  45581 non-null object
# SERVER_NAME                45581 non-null object
# DOWNLOAD_KBPS              45581 non-null int64
# UPLOAD_KBPS                45581 non-null int64
# LATENCY                    45581 non-null int64
# CLIENT_BROWSER             45581 non-null object
# CLIENT_OPERATING_SYSTEM    45581 non-null object
# USER_AGENT                 45581 non-null object
# dtypes: float64(2), int64(3), object(7)
# memory usage: 4.5+ MB

# %%
df['CLIENT_COUNTRY'].nunique()
# Out:
# 1

# %%
# Siccome COUNTRY c'è solo un valore posso eliminare la colonna
df = df.drop('CLIENT_COUNTRY', axis=1)

# %% [markdown]
# ### Get mean in Download / Upload / Latency for each CITY

# %%
cities = df.groupby('CLIENT_CITY')
cities.size()
# Out:
# CLIENT_CITY
# Abbiategrasso              2
# Acerra                     3
# Acqui Terme               48
# Airasca                    1
# Alassio                   29
# Alba                      81
# Albenga                    2
# Albisola Superiore        16
# Alessandria              728
# Alfiano Natta              2
# Almese                     4
# Alpignano                 22
# Ancona                     2
# Andora                     2
# Aosta                     18
# Arcore                     1
# Arenzano                   1
# Assago                     1
# Asti                     789
# Avellino                   1
# Avigliana                122
# Ayas                       4
# Badia Polesine            19
# Baldissero Torinese        4
# Bandito                    7
# Bardonecchia               5
# Bari                       2
# Bassano Del Grappa         1
# Beinasco                  23
# Bergamo                    2
#                        ...
# Tortona                    7
# Trecate                    1
# Trento                     4
# Treviglio                  7
# Trezzo Sull'adda           1
# Trofarello                52
# Turin                  37687
# Vallecrosia               11
# Varese                     1
# Venaria                   14
# Venaria Reale              7
# Venice                     1
# Ventimiglia                3
# Vercelli                  59
# Verona                    18
# Viareggio                  1
# Vicolungo                 12
# Vigevano                  16
# Vignole                   12
# Vignolo                    1
# Vigone                    19
# Villanova Mondovì          1
# Villar Focchiardo          1
# Villaromagnano             1
# Villastellone              5
# Vimercate                  2
# Vimodrone                  1
# Viverone                   2
# Voghera                   53
# Volpiano                   6
# Length: 230, dtype: int64

# %%
# Siccome COUNTRY c'è solo un valore posso eliminare la colonna
df = df.drop('CLIENT_COUNTRY', axis=1)

# %%
result = cities.agg({'DOWNLOAD_KBPS': ['mean'],
            'UPLOAD_KBPS': ['mean'],
            'LATENCY': ['mean']
           })

# %%
result
# Out:
#                       UPLOAD_KBPS DOWNLOAD_KBPS     LATENCY
#                              mean          mean        mean
# CLIENT_CITY
# Abbiategrasso         1210.500000   2008.000000  126.500000
# Acerra                 675.333333   5158.666667   49.000000
# Acqui Terme           5468.354167  26109.333333   23.520833
# Airasca                435.000000   3238.000000   46.000000
# Alassio               2230.758621   7054.896552   53.689655
# Alba                  3315.740741   8325.481481   33.012346
# Albenga                520.000000   2568.000000   33.000000
# Albisola Superiore    2893.125000  10964.250000   30.187500
# Alessandria          10338.130495  26911.537088   28.678571
# Alfiano Natta          844.000000   5220.500000   12.000000
# Almese                1178.750000   1011.500000  522.000000
# Alpignano              728.954545   5892.454545   28.090909
# Ancona                2458.000000   3907.000000   42.500000
# Andora                 328.000000   9169.000000  127.000000
# Aosta                 7892.166667   9708.166667   13.333333
# Arcore                2827.000000   9382.000000  166.000000
# Arenzano               912.000000  10200.000000   34.000000
# Assago                3591.000000   4079.000000   72.000000
# Asti                  8400.648923  28851.707224   38.128010
# Avellino               724.000000   3717.000000   43.000000
# Avigliana             4446.819672  12607.795082  176.450820
# Ayas                   550.500000   4718.750000  139.500000
# Badia Polesine       22083.736842  50469.947368   18.842105
# Baldissero Torinese    485.000000   8823.000000   32.500000
# Bandito                611.428571   4698.428571   29.285714
# Bardonecchia           796.200000  11322.400000   36.200000
# Bari                  8428.500000  21968.000000   38.000000
# Bassano Del Grappa     810.000000  11553.000000   82.000000
# Beinasco              2463.130435   8302.608696   24.565217
# Bergamo              12692.500000  45744.500000   26.000000
# ...                           ...           ...         ...
# Tortona              10632.571429  16628.285714   20.857143
# Trecate                506.000000   5537.000000   55.000000
# Trento                 717.250000  14322.250000   56.250000
# Treviglio             1082.428571   4658.000000   88.857143
# Trezzo Sull'adda       977.000000   3707.000000   44.000000
# Trofarello             536.000000   3954.769231  116.903846
# Turin                 8706.158861  25187.663916   38.233184
# Vallecrosia            490.363636   3684.727273   48.727273
# Varese               10152.000000  24983.000000   24.000000
# Venaria              25428.214286  23730.642857    8.928571
# Venaria Reale         6087.428571  24716.285714   23.857143
# Venice                 856.000000  10434.000000   25.000000
# Ventimiglia            398.333333   1031.666667   72.666667
# Vercelli              2444.661017  10763.322034   69.135593
# Verona                3747.944444  25415.111111   39.388889
# Viareggio             5785.000000   4246.000000   24.000000
# Vicolungo             2171.583333  14525.250000   56.500000
# Vigevano              8465.125000  20076.750000  102.312500
# Vignole                571.000000   7296.250000   49.333333
# Vignolo                489.000000   8891.000000   27.000000
# Vigone                3433.578947  11322.210526   51.315789
# Villanova Mondovì    17815.000000  15878.000000    9.000000
# Villar Focchiardo      613.000000   1752.000000   29.000000
# Villaromagnano         855.000000  14089.000000   25.000000
# Villastellone         9958.400000   7477.400000    8.400000
# Vimercate             9985.000000  39288.500000   22.000000
# Vimodrone             9703.000000  94151.000000   29.000000
# Viverone               380.000000   9529.500000   26.500000
# Voghera               8171.226415  23950.905660   51.679245
# Volpiano              4183.000000   4605.833333   13.833333
#
# [230 rows x 3 columns]

# %% [markdown]
# # Find Operating Systems frequency
#
# Attention, we have some empty values..!

# %%
df['CLIENT_OPERATING_SYSTEM'].value_counts()df['CLIENT_OPERATING_SYSTEM'].unique()
# Out:
# Windows          21444
# Windows 7        13562
# Mac OS X          7042
# Windows XP        1366
# Linux              785
# Windows Vista      671
# Linux ubuntu       580
# Windows 2003        52
# Windows 2000        49
# ChromeOS            21
#                      8
# Window               1
# Name: CLIENT_OPERATING_SYSTEM, dtype: int64

# %%
df['CLIENT_OPERATING_SYSTEM'].unique()
# Out:
# array(['Windows 7', 'Windows ', 'Linux ', 'Windows XP', 'Mac OS X',
#        'Windows Vista', 'Linux ubuntu', 'ChromeOS ', ' ', 'Windows 2003',
#        'Windows 2000', 'Window '], dtype=object)

# %%
def clean_field(element):
    if element == ' ':
        return 'Not Identified'
    return element

# %%
df['CLIENT_OPERATING_SYSTEM'] = df['CLIENT_OPERATING_SYSTEM'].apply(clean_field)

# %%
df['CLIENT_OPERATING_SYSTEM'].unique()
# Out:
# array(['Windows 7', 'Windows ', 'Linux ', 'Windows XP', 'Mac OS X',
#        'Windows Vista', 'Linux ubuntu', 'ChromeOS ', 'Not Identified',
#        'Windows 2003', 'Windows 2000', 'Window '], dtype=object)

# %%
# normalize operating system
def normalize_os(element):
    if 'Window' in element:
        return 'Windows'
    elif 'Linux' in element:
        return 'Linux'
    return element

# %%
df['CLIENT_OPERATING_SYSTEM'] = df['CLIENT_OPERATING_SYSTEM'].apply(normalize_os)
df['CLIENT_OPERATING_SYSTEM'].unique()
# Out:
# array(['Windows', 'Linux', 'Mac OS X', 'ChromeOS ', 'Not Identified'], dtype=object)

# %%
df['CLIENT_OPERATING_SYSTEM'].value_counts()
# Out:
# Windows           37145
# Mac OS X           7042
# Linux              1365
# ChromeOS             21
# Not Identified        8
# Name: CLIENT_OPERATING_SYSTEM, dtype: int64

# %% [markdown]
# # Find Browser frequency
#
# Attention, we have some empty values..!

# %%
# Same Operation for Browser
df['CLIENT_BROWSER'].unique()
# Out:
# array(['Chrome 47.0.2526.106', 'Firefox 43.0', 'Firefox 38.0',
#        'Chrome 30.0.1599.114', 'Internet Explorer 11.0',
#        'Chrome 46.0.2486.0', 'Safari 9.0.3', 'Safari 9.0.2',
#        'Chrome 47.0.2526.80', 'Internet Explorer 8.0',
#        'Chrome 46.0.2490.86', 'Safari 2.3', 'Firefox 26.0', 'Safari 9.0.1',
#        'Chrome 46.0.2490.80', 'Chrome 42.0.2311.135', 'Firefox 39.0',
#        'Opera 34.0.2036.25', 'Chrome 37.0.2062.120', 'Firefox 24.0',
#        'Chrome 22.0.1229.79', 'Firefox 42.0', 'Chrome 45.0.2454.101',
#        'Firefox 34.0', 'Firefox 45.0', 'Safari 8.0.8', 'Safari 9.0',
#        'Internet Explorer 10.0', 'Chrome 25.0.1349.2', 'Firefox 41.0',
#        'Chrome 47.0.2500.0', 'Internet Explorer 9.0', 'Opera 32.0.1948.25',
#        'Chrome 11.0.696.34', 'Safari 6.1.6', 'Chrome 30.0.1599.101',
#        'Chrome 48.0.2564.48', 'Opera 34.0.2036.39', 'Opera 33.0.1990.115',
#        'Chrome 34.0.1847.132', 'Firefox 31.9', 'Chrome 41.0.2272.118',
#        'Firefox 44.0', 'Chrome 45.0.2454.93', 'Safari 6.2.7',
#        'Firefox 40.0', 'Safari 5.1.9', 'Chrome 44.0.2403.89',
#        'Firefox 31.0', 'Chrome 47.0.2526.73', 'Firefox 27.0',
#        'Opera 34.0.2036.41', 'Chrome 39.0.2171.99', 'Safari 7.0.6',
#        'Firefox 40.1.0', 'Safari 8.0.5', 'Chrome 43.0.2357.134',
#        'Chrome 43.0.2357.124', 'Chrome 34.0.1847.137',
#        'Internet Explorer 7.0', 'Chrome 36.0.1985.97', 'Safari 6.2.6',
#        'Chrome 44.0.2403.157', 'Safari 8.0.3', 'unknown unknown',
#        'Safari 8.0.7', 'Safari 5.0', 'Mozilla 5.0', 'Safari 7.1.8',
#        'Firefox 30.0', 'Chrome 46.0.2490.52', 'Chrome 46.0.2490.71',
#        'Chrome 49.0.2612.0', 'Chrome 44.0.2403.107', 'Chrome 45.0.2454.99',
#        'Firefox 35.0', 'Safari 8.0', 'Chrome 43.0.2357.81', 'Opera 12.16',
#        'Chrome 49.0.2617.0', 'Chrome 45.0.2454.85', 'Chrome 39.0.2171.95',
#        'Firefox 3.6.18', 'Chrome 48.0.2564.71', 'Chrome 47.0.2526.83',
#        'Firefox 36.0', 'Chrome 48.0.2564.41', 'Chrome 42.0.2311.90',
#        'Safari 7.0.5', 'Chrome 39.0.2171.71', 'Chrome 31.0.1650.59',
#        'Chrome 35.0.1916.153', 'Chrome 43.0.2357.132',
#        'Opera 22.0.1485.80265', 'Firefox 32.0', 'Opera 34.0.2036.47',
#        'Chrome 47.0.2526.111', 'Safari 4.1.3', 'Opera 34.0.2036.42',
#        'Firefox 33.0', 'Chrome 49.0.2618.8', 'GoogleBot 2.1',
#        'Chrome 47.6.2526.80', 'Opera 29.0.1795.47', 'Chrome 35.0.1916.114',
#        'Chrome 48.0.2564.79', 'Opera 32.0.1948.69', 'Chrome 47.4.2526.80',
#        'Chrome 40.0.2214.115', 'Safari 6.2.3', 'Firefox 37.0',
#        'Chrome 38.0.2125.104', 'Safari 6.0.5', 'Chrome 23.0.1271.64',
#        'Firefox 11.0', 'Chrome 48.0.2564.82', 'Safari 5.0.6',
#        'Chrome 49.0.2623.0', 'Chrome 47.0.2526.69', 'Safari 9.1',
#        'Firefox 43.0.4', 'Opera 34.0.2036.50', 'Safari 7.1.6',
#        'Chrome 26.0.1410.64', 'Chrome 18.0.1025.54', 'Safari 6.2.8',
#        'Firefox 3.6.3', 'Chrome 29.0.1547.57', 'Chrome 42.0.2311.152',
#        'Firefox 3.6.16', 'Chrome 31.0.1650.63', 'Firefox 22.0',
#        'Firefox 21.0', 'Opera 22.0.1481.0', 'Android 3.2',
#        'Chrome 43.0.2357.130', 'Safari 8.0.6', 'Chrome 38.0.2125.92',
#        'Chrome 48.0.2564.97', 'Chrome 25.0.1364.99', 'Chrome 49.0.2623.23',
#        'Chrome 33.0.0.0', 'Firefox 13.0.1', 'Safari 8.0.2',
#        'Chrome 40.0.2214.93', 'Chrome 32.0.1700.102',
#        'Chrome 23.0.1271.97', 'Chrome 34.0.1850.0', 'Chrome 45.1.2454.18',
#        'Chrome 50.0.2631.0', 'Chrome 45.0.0.10802', 'Chrome 49.0.2623.28',
#        'Chrome 48.0.2564.92', 'Chrome 37.0.2062.124', 'Firefox 23.0',
#        'Safari 7.1.2', 'Chrome 50.0.2633.3', 'Firefox 8.0.1',
#        'Chrome 26.0.1410.33', 'Chrome 48.0.2564.103',
#        'Chrome 41.0.2272.101', 'Opera 35.0.2066.37', 'Chrome 22.0.1229.94',
#        'Chrome 50.0.2640.0', 'Chrome 40.0.2214.91', 'Firefox 16.0',
#        'Chrome 50.0.2638.0', 'Safari 5.0.2', 'Firefox 40.0.2',
#        'Chrome 46.0.2472.0', 'Chrome 46.17.2490.86', 'Chrome 37.0.2062.99',
#        'Chrome 49.0.2623.39', 'Chrome 32.0.1700.107', 'Safari 8.0.4',
#        'Safari 5.1.7', 'Chrome 48.0.2564.109', 'Chrome 48.2.2564.88',
#        'Chrome 50.0.2647.0', 'Chrome 27.0.1453.93', 'Chrome 43.0.2357.125',
#        'Chrome 46.0.2480.0', 'Safari 4.0', 'Chrome 49.0.2623.47',
#        'Chrome 34.0.1847.116', 'Chrome 48.0.2550.0', 'Opera 12.17',
#        'Chrome 25.0.1364.97', 'Safari 2156', 'Chrome 44.0.2403.155',
#        'Chrome 38.0.2125.122', 'Chrome 47.0.2526.100',
#        'Chrome 35.0.1849.0', 'Firefox 29.0', 'Firefox 46.0',
#        'Chrome 48.0.2564.116', 'Opera 12.13', 'Chrome 33.0.1750.154',
#        'Chrome 49.0.2623.54', 'Chrome 48.0.2564.95', 'Opera 35.0.2066.68',
#        'Firefox 38.9', 'Safari 7.0', 'Chrome 49.0.2623.56',
#        'Chrome 43.0.2357.65', 'Safari unknown', 'Chrome 40.0.2214.111',
#        'Chrome 50.0.2657.0', 'Opera 26.0.1656.60', 'Chrome 50.0.2658.0',
#        'Opera 35.0.2066.82', 'Chrome 48.5.2564.88', 'Chrome 39.0.2146.0',
#        'Chrome 38.0.2125.111', 'Chrome 50.0.2659.0', 'Chrome 44.0.2367.0',
#        'Chrome 49.0.2623.63', 'Chrome 36.0.1985.125', 'Chrome 50.0.2650.0',
#        'Safari 5.0.5', 'Chrome 49.0.2623.64', 'Chrome 38.0.2125.19',
#        'Chrome 49.0.2623.75', 'Firefox 25.0', 'Opera 35.0.2066.92',
#        'Chrome 50.0.2661.11', 'Firefox 20.0', 'Firefox 12.0',
#        'Chrome 45.0.2453.0', 'Chrome 48.0.2559.2', 'Chrome 34.0.1847.76',
#        'Chrome 26.0.1410.63', 'Chrome 49.0.2623.87', 'Chrome 51.0.2670.0',
#        'Chrome 45.0.2454.104', 'Chrome 45.0.0.11014', 'Opera 23.0.1522.77',
#        'Chrome 50.0.2661.26', 'Chrome 44.0.2403.125', 'Opera 23.0.1522.60',
#        'Chrome 44.0.2403.130', 'Chrome 50.0.2661.18', 'Opera 36.0.2130.32',
#        'Safari 7.0.2', 'Chrome 41.0.2228.0', 'Chrome 51.0.2682.0',
#        'Chrome 50.0.2661.37', 'Firefox 44.0.3', 'Chrome 49.0.2623.108',
#        'Chrome 50.0.2655.0', 'Chrome 49.0.2623.91', 'Safari 2249',
#        'Chrome 49.0.2623.110', 'Firefox 47.0', 'Chrome 50.0.2661.49',
#        'Chrome 51.0.2687.0', 'Opera 36.0.2130.46', 'Chrome 49.0.2623.105',
#        'Chrome 41.0.2272.89',
#        'Internet Explorer 11.01.47.159.4009.3.7101.400',
#        'Chrome 50.0.2661.57', 'Chrome 51.0.2691.0', 'Chrome 51.0.2693.2',
#        'Chrome 50.0.2661.66', 'Chrome 34.0.1847.131',
#        'Chrome 49.0.2623.112', 'Chrome 37.0.2049.0', 'Safari 9.1.1',
#        'Chrome 51.0.2700.0', 'Chrome 36.0.1985.143', 'Opera 36.0.2130.65',
#        'Chrome 50.0.2661.75', 'Chrome 11.0.696.60', 'Chrome 51.0.2704.5',
#        'Chrome 25.0.1364.172', 'Chrome 47.5.2526.111',
#        'Chrome 50.0.2632.0', 'Chrome 51.0.2704.7', 'Chrome 39.0.2171.65',
#        'Firefox 19.0', 'Chrome 26.0.1410.40', 'Chrome 50.0.2661.86',
#        'Chrome 50.0.2661.87', 'Chrome 51.0.2704.19', 'Chrome 51.0.2704.22',
#        'Chrome 50.2.2661.78', 'Chrome 34.0.1838.2', 'Chrome 52.0.2718.0',
#        'Chrome 40.0.2214.94', 'Chrome 40.0.2214.45', 'Chrome 50.0.2661.94',
#        'Chrome 52.0.2716.0', 'Chrome 51.0.2704.29', 'Chrome 52.0.2720.0',
#        'Chrome 48.4.2564.88', 'Chrome 50.3.2661.78', 'Firefox 9.0.1',
#        'Chrome 32.0.1700.76', 'Opera 11.61', 'Opera 37.0.2178.32',
#        'Chrome 51.0.2704.36', 'Chrome 52.0.2723.2', 'Chrome 47.0.2498.0',
#        'Chrome 50.0.2661.89', 'Chrome 36.0.1950.0', 'Opera 12.18',
#        'Chrome 52.0.2729.4', 'Chrome 50.0.2661.102', 'Chrome 50.4.2661.78',
#        'Firefox 46.0.1', 'Opera 37.0.2178.43', 'Opera 39.0.2226.0',
#        'iPhone 9.3.1', 'Chrome 49.0.2600.0', 'Firefox 48.0',
#        'Chrome 52.0.2739.0', 'Chrome 50.14.2661.78', 'Chrome 51.0.2704.47'], dtype=object)

# %%
# normalize browser
def normalize_browser(element):
    if 'Chrome' in element:
        return 'Chrome'
    elif 'Firefox' in element:
        return 'Firefox'
    elif 'Opera' in element:
        return 'Opera'
    elif 'Safari' in element:
        return 'Safari'
    elif 'Explorer' in element:
        return 'Internet Explorer'
    else:
        return element

# %%
df['CLIENT_BROWSER'] = df['CLIENT_BROWSER'].apply(normalize_browser)
print df['CLIENT_BROWSER'].unique()
print df['CLIENT_BROWSER'].value_counts()
# Out:
# ['Chrome' 'Firefox' 'Internet Explorer' 'Safari' 'Opera' 'unknown unknown'
#  'Mozilla 5.0' 'GoogleBot 2.1' 'Android 3.2' 'iPhone 9.3.1']
# Chrome               28075
# Firefox               9672
# Safari                3964
# Internet Explorer     3552
# Opera                  297
# Mozilla 5.0             12
# unknown unknown          5
# GoogleBot 2.1            2
# Android 3.2              1
# iPhone 9.3.1             1
# Name: CLIENT_BROWSER, dtype: int64

# %% [markdown]
# # Get Max Entry on DOWNLOAD for each city

# %%
cities = df.groupby('CLIENT_CITY')

# %%
entries = pd.DataFrame(columns=df.columns)
entries
# Out:
# Empty DataFrame
# Columns: [CLIENT_CITY, CLIENT_LATITUDE, CLIENT_LONGITUDE, TEST_DATE, SERVER_NAME, DOWNLOAD_KBPS, UPLOAD_KBPS, LATENCY, CLIENT_BROWSER, CLIENT_OPERATING_SYSTEM, USER_AGENT]
# Index: []

# %%
for city, value in cities:
    highest = value.nlargest(1, 'DOWNLOAD_KBPS')
    entries = entries.append(highest)

# %%
entries
# Out:
#                 CLIENT_CITY  CLIENT_LATITUDE  CLIENT_LONGITUDE  \
# 112958        Abbiategrasso          45.4000            8.9000
# 155412               Acerra          40.9448           14.3714
# 21334           Acqui Terme          44.6755            8.4693
# 155541              Airasca          44.9172            7.4832
# 26866               Alassio          44.0039            8.1671
# 48606                  Alba          44.7000            8.0333
# 91242               Albenga          44.0500            8.2183
# 76006    Albisola Superiore          44.3389            8.5105
# 88305           Alessandria          44.9000            8.6167
# 6332          Alfiano Natta          45.0486            8.2073
# 17069                Almese          45.1167            7.3833
# 23562             Alpignano          45.0935            7.5239
# 38671                Ancona          43.5942           13.5034
# 12444                Andora          43.9551            8.1412
# 26340                 Aosta          45.7376            7.3172
# 132690               Arcore          45.6267            9.3245
# 36229              Arenzano          44.4052            8.6831
# 153257               Assago          45.4089            9.1256
# 187513                 Asti          44.9016            8.2075
# 137961             Avellino          40.9149           14.7910
# 596               Avigliana          45.0798            7.3965
# 1183                   Ayas          45.8148            7.6893
# 82454        Badia Polesine          45.0951           11.4944
# 183671  Baldissero Torinese          45.0667            7.8167
# 124512              Bandito          44.7228            7.8240
# 25706          Bardonecchia          45.0746            6.6989
# 10194                  Bari          41.1115           16.8554
# 103135   Bassano Del Grappa          45.7666           11.7274
# 151964             Beinasco          45.0247            7.5856
# 20931               Bergamo          45.6960            9.6672
# ...                     ...              ...               ...
# 126974              Tortona          44.8289            8.8528
# 4215                Trecate          45.4340            8.7364
# 15823                Trento          46.0667           11.1333
# 106581            Treviglio          45.5507            9.5780
# 70964      Trezzo Sull'adda          45.5982            9.5057
# 164370           Trofarello          44.9824            7.7469
# 83341                 Turin          45.0705            7.6868
# 201             Vallecrosia          43.8000            7.6500
# 112548               Varese          45.7908            8.8515
# 180402              Venaria          45.1333            7.6333
# 80048         Venaria Reale          45.1333            7.6500
# 182718               Venice          45.4386           12.3267
# 177550          Ventimiglia          43.8248            7.5782
# 70441              Vercelli          45.3126            8.4992
# 15097                Verona          45.4299           10.9844
# 62463             Viareggio          43.8667           10.2333
# 91736             Vicolungo          45.4833            8.4667
# 41470              Vigevano          45.2890            8.8866
# 17642               Vignole          46.1500           12.1333
# 172519              Vignolo          44.3667            7.4667
# 33665                Vigone          44.8424            7.4977
# 146901    Villanova Mondovì          44.3361            7.8245
# 80486     Villar Focchiardo          45.1116            7.2364
# 73708        Villaromagnano          44.8496            8.8878
# 8652          Villastellone          44.9220            7.7436
# 27383             Vimercate          45.6167            9.3667
# 11541             Vimodrone          45.5000            9.2667
# 100083             Viverone          45.4273            8.0494
# 181221              Voghera          44.9833            9.0167
# 53696              Volpiano          45.1994            7.7755
#
#                      TEST_DATE SERVER_NAME DOWNLOAD_KBPS UPLOAD_KBPS LATENCY  \
# 112958  3/12/2016 20:29:58 GMT       Turin          3752        1628      46
# 155412  4/13/2016 16:06:31 GMT       Turin         10000         556      44
# 21334   1/15/2016 20:50:18 GMT       Turin         94871        9544      19
# 155541  4/13/2016 16:58:16 GMT       Turin          3238         435      46
# 26866   1/19/2016 14:48:52 GMT       Turin         20453       18490      10
# 48606    2/2/2016 14:58:41 GMT       Turin         84570       44744       0
# 91242   2/28/2016 14:40:01 GMT       Turin          4271         628      36
# 76006   2/18/2016 19:42:32 GMT       Turin         52736        9567       5
# 88305   2/26/2016 15:49:38 GMT       Turin         95555       97373      10
# 6332     1/5/2016 21:08:17 GMT       Turin          5260         843      12
# 17069   1/13/2016 13:06:49 GMT       Turin          1519        1651       9
# 23562   1/17/2016 13:09:25 GMT       Turin         13678         818      30
# 38671   1/27/2016 07:33:13 GMT       Turin          4611        4478      43
# 12444   1/10/2016 13:29:58 GMT       Turin         15976         418      40
# 26340   1/19/2016 09:12:08 GMT       Turin         28926       23428      11
# 132690  3/27/2016 16:49:18 GMT       Turin          9382        2827     166
# 36229   1/25/2016 17:13:52 GMT       Turin         10200         912      34
# 153257  4/12/2016 12:24:48 GMT       Turin          4079        3591      72
# 187513   5/9/2016 18:37:12 GMT       Turin        498367       49895       1
# 137961  3/31/2016 18:50:17 GMT       Turin          3717         724      43
# 596      1/1/2016 17:37:19 GMT       Turin         93766       78211       6
# 1183     1/2/2016 09:32:47 GMT       Turin          9193         565      27
# 82454   2/23/2016 09:33:41 GMT       Turin         83176       32152      18
# 183671   5/6/2016 10:03:04 GMT       Turin         10563         501      26
# 124512  3/21/2016 06:12:18 GMT       Turin         10572         865      28
# 25706   1/18/2016 19:19:27 GMT       Turin         16772         850      33
# 10194    1/8/2016 18:26:16 GMT       Turin         23369        6956      38
# 103135   3/6/2016 20:47:24 GMT       Turin         11553         810      82
# 151964  4/11/2016 13:03:36 GMT       Turin         25457       27970       7
# 20931   1/15/2016 16:53:43 GMT       Turin         67244        9978      23
# ...                        ...         ...           ...         ...     ...
# 126974  3/22/2016 20:16:11 GMT       Turin         33907       33077       8
# 4215     1/4/2016 16:31:17 GMT       Turin          5537         506      55
# 15823   1/12/2016 17:42:28 GMT       Turin         16928         883      24
# 106581   3/9/2016 08:56:56 GMT       Turin          9983         840      26
# 70964   2/15/2016 21:35:19 GMT       Turin          3707         977      44
# 164370  4/20/2016 12:58:41 GMT       Turin          9404         885      34
# 83341   2/23/2016 18:19:29 GMT       Turin        841588      743541       6
# 201      1/1/2016 12:06:00 GMT       Turin          5951         493      50
# 112548  3/12/2016 16:02:48 GMT       Turin         24983       10152      24
# 180402   5/3/2016 18:19:49 GMT       Turin         48666       40777       9
# 80048   2/21/2016 14:45:50 GMT       Turin         76557       10024      22
# 182718   5/5/2016 13:52:29 GMT       Turin         10434         856      25
# 177550   5/1/2016 16:36:54 GMT       Turin          1115         243      29
# 70441   2/15/2016 17:05:53 GMT       Turin         85860       10066      21
# 15097   1/12/2016 10:01:53 GMT       Turin         85442       10078      22
# 62463   2/10/2016 15:41:26 GMT       Turin          4246        5785      24
# 91736   2/28/2016 19:27:46 GMT       Turin         67056       10081      24
# 41470   1/28/2016 19:20:30 GMT       Turin         94970        9818       8
# 17642   1/13/2016 17:56:13 GMT       Turin         10592         805      29
# 172519  4/27/2016 17:28:30 GMT       Turin          8891         489      27
# 33665   1/23/2016 19:15:03 GMT       Turin         29589       10045      23
# 146901   4/7/2016 08:05:56 GMT       Turin         15878       17815       9
# 80486   2/21/2016 20:30:12 GMT       Turin          1752         613      29
# 73708   2/17/2016 16:01:55 GMT       Turin         14089         855      25
# 8652     1/7/2016 18:24:56 GMT       Turin          9639        9981       8
# 27383   1/19/2016 19:28:04 GMT       Turin         49083        9963      22
# 11541    1/9/2016 16:48:17 GMT       Turin         94151        9703      29
# 100083   3/4/2016 21:49:57 GMT       Turin         13762         351      28
# 181221   5/4/2016 13:10:51 GMT       Turin         95126       96155       7
# 53696    2/5/2016 12:38:30 GMT       Turin         13344        6243       6
#
#            CLIENT_BROWSER CLIENT_OPERATING_SYSTEM  \
# 112958             Chrome                 Windows
# 155412            Firefox                 Windows
# 21334              Chrome                 Windows
# 155541             Chrome                Mac OS X
# 26866             Firefox                 Windows
# 48606   Internet Explorer                 Windows
# 91242              Chrome                 Windows
# 76006              Chrome                 Windows
# 88305   Internet Explorer                 Windows
# 6332               Chrome                 Windows
# 17069             Firefox                 Windows
# 23562              Chrome                 Windows
# 38671             Firefox                 Windows
# 12444              Chrome                 Windows
# 26340   Internet Explorer                 Windows
# 132690             Chrome                 Windows
# 36229             Firefox                   Linux
# 153257             Chrome                 Windows
# 187513             Chrome                 Windows
# 137961             Chrome                 Windows
# 596     Internet Explorer                 Windows
# 1183    Internet Explorer                 Windows
# 82454              Chrome                 Windows
# 183671            Firefox                 Windows
# 124512             Chrome                 Windows
# 25706              Safari                Mac OS X
# 10194              Chrome                 Windows
# 103135             Chrome                 Windows
# 151964             Chrome                 Windows
# 20931   Internet Explorer                 Windows
# ...                   ...                     ...
# 126974            Firefox                 Windows
# 4215               Chrome                 Windows
# 15823             Firefox                 Windows
# 106581             Chrome                 Windows
# 70964   Internet Explorer                 Windows
# 164370             Chrome                 Windows
# 83341             Firefox                 Windows
# 201                Chrome                 Windows
# 112548             Chrome                 Windows
# 180402             Chrome                 Windows
# 80048             Firefox                 Windows
# 182718             Chrome                 Windows
# 177550             Chrome                 Windows
# 70441             Firefox                 Windows
# 15097             Firefox                 Windows
# 62463              Chrome                 Windows
# 91736              Chrome                Mac OS X
# 41470             Firefox                 Windows
# 17642              Chrome                 Windows
# 172519            Firefox                   Linux
# 33665              Chrome                 Windows
# 146901             Chrome                 Windows
# 80486               Opera                 Windows
# 73708              Chrome                 Windows
# 8652               Chrome                 Windows
# 27383              Chrome                 Windows
# 11541              Safari                Mac OS X
# 100083             Chrome                 Windows
# 181221            Firefox                 Windows
# 53696   Internet Explorer                 Windows
#
#                                                USER_AGENT
# 112958  Mozilla/5.0 (Windows NT 6.2; WOW64) AppleWebKi...
# 155412  Mozilla/5.0 (Windows NT 10.0; WOW64; rv:45.0) ...
# 21334   Mozilla/5.0 (Windows NT 6.0) AppleWebKit/537.3...
# 155541  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_5...
# 26866   Mozilla/5.0 (Windows NT 5.1; rv:43.0) Gecko/20...
# 48606   Mozilla/5.0 (Windows NT 6.1; WOW64; Trident/7....
# 91242   Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...
# 76006   Mozilla/5.0 (Windows NT 6.2; WOW64) AppleWebKi...
# 88305   Mozilla/4.0 (compatible; MSIE 8.0; Windows NT ...
# 6332    Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKi...
# 17069   Mozilla/5.0 (Windows NT 10.0; rv:43.0) Gecko/2...
# 23562   Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKi...
# 38671   Mozilla/5.0 (Windows NT 6.1; rv:42.0) Gecko/20...
# 12444   Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...
# 26340   Mozilla/5.0 (compatible; MSIE 10.0; Windows NT...
# 132690  Mozilla/5.0 (Windows NT 10.0; WOW64) AppleWebK...
# 36229   Mozilla/5.0 (X11; Linux i686; rv:22.0) Gecko/2...
# 153257  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...
# 187513  Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKi...
# 137961  Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.3...
# 596     Mozilla/5.0 (Windows NT 10.0; WOW64; Trident/7...
# 1183    Mozilla/5.0 (Windows NT 6.1; Trident/7.0; rv:1...
# 82454   Mozilla/5.0 (Windows NT 10.0; WOW64) AppleWebK...
# 183671  Mozilla/5.0 (Windows NT 10.0; WOW64; rv:45.0) ...
# 124512  Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebKi...
# 25706   Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_2...
# 10194   Mozilla/5.0 (Windows NT 10.0; WOW64) AppleWebK...
# 103135  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...
# 151964  Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKi...
# 20931   Mozilla/5.0 (compatible; MSIE 10.0; Windows NT...
# ...                                                   ...
# 126974  Mozilla/5.0 (Windows NT 10.0; WOW64; rv:39.0) ...
# 4215    Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...
# 15823   Mozilla/5.0 (Windows NT 6.1; WOW64; rv:43.0) G...
# 106581  Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKi...
# 70964   Mozilla/5.0 (Windows NT 6.1; WOW64; Trident/7....
# 164370  Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKi...
# 83341   Mozilla/5.0 (Windows NT 6.1; WOW64; rv:44.0) G...
# 201     Mozilla/5.0 (Windows NT 10.0; WOW64) AppleWebK...
# 112548  Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKi...
# 180402  Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKi...
# 80048   Mozilla/5.0 (Windows NT 6.0; rv:44.0) Gecko/20...
# 182718  Mozilla/5.0 (Windows NT 5.1) AppleWebKit/537.3...
# 177550  Mozilla/5.0 (Windows NT 10.0; WOW64) AppleWebK...
# 70441   Mozilla/5.0 (Windows NT 6.1; rv:44.0) Gecko/20...
# 15097   Mozilla/5.0 (Windows NT 5.1; rv:43.0) Gecko/20...
# 62463   Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebKi...
# 91736   Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_5)...
# 41470   Mozilla/5.0 (Windows NT 6.3; WOW64; rv:35.0) G...
# 17642   Mozilla/5.0 (Windows NT 10.0; WOW64) AppleWebK...
# 172519  Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:45....
# 33665   Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKi...
# 146901  Mozilla/5.0 (Windows NT 10.0; WOW64) AppleWebK...
# 80486   Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKi...
# 73708   Mozilla/5.0 (Windows NT 10.0; WOW64) AppleWebK...
# 8652    Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKi...
# 27383   Mozilla/5.0 (Windows NT 10.0; WOW64) AppleWebK...
# 11541   Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_2...
# 100083  Mozilla/5.0 (Windows NT 6.2; WOW64) AppleWebKi...
# 181221  Mozilla/5.0 (Windows NT 5.1; rv:45.0) Gecko/20...
# 53696   Mozilla/5.0 (Windows NT 6.3; WOW64; Trident/7....
#
# [230 rows x 11 columns]

# %% [markdown]
# # Play alone with the dataset!

# %%
print 'Hello!'
# Out:
# Hello!
