# %% [markdown]
# # Pandas
#
# **pandas** is an open source, BSD-licensed library providing high-performance, easy-to-use data structures and data analysis tools for the Python programming language.

# %% [markdown]
# ## SERIES
# Series is a one-dimensional labeled array capable of holding any data type (integers, strings, floating point numbers, Python objects, etc.). The axis labels are collectively referred to as the index.

# %%
import pandas as pd

# %%
simple_list = ["one", "two", "three"]

# %%
pd.Series(simple_list)
pd.Series(data=simple_list)
# Out:
# 0      one
# 1      two
# 2    three
# dtype: object

# %%
simple_list_integers = [100,200,300]
pd.Series(simple_list_integers)
# Out:
# 0    100
# 1    200
# 2    300
# dtype: int64

# %%
simple_list_of_mix_values = [1, True, "Hello", None, [0, 9, 8], {"name": "Pandas"}]

# %%
pd.Series(simple_list_of_mix_values)
# Out:
# 0                       1
# 1                    True
# 2                   Hello
# 3                    None
# 4               [0, 9, 8]
# 5    {u'name': u'Pandas'}
# dtype: object

# %% [markdown]
# # Create Series From Python Dictionary

# %%
simple_dict = {"first_name": "Steve", 
               "last_name": "Flurry",
               "age": 17,
               "age": 22}
simple_dict
# Out:
# {'age': 22, 'first_name': 'Steve', 'last_name': 'Flurry'}

# %%
pd.Series(simple_dict)
# Out:
# age               22
# first_name     Steve
# last_name     Flurry
# dtype: object

# %% [markdown]
# ### Series Attributes

# %%
#print simple_list
s = pd.Series(simple_list)
s.head(1)
s.tail()
# Out:
# 0      one
# 1      two
# 2    three
# dtype: object

# %%
s
# Out:
# 0      one
# 1      two
# 2    three
# dtype: object

# %%
print dir(s)
# Out:
# ['T', '_AXIS_ALIASES', '_AXIS_IALIASES', '_AXIS_LEN', '_AXIS_NAMES', '_AXIS_NUMBERS', '_AXIS_ORDERS', '_AXIS_REVERSED', '_AXIS_SLICEMAP', '__abs__', '__add__', '__and__', '__array__', '__array_prepare__', '__array_priority__', '__array_wrap__', '__bool__', '__bytes__', '__class__', '__contains__', '__copy__', '__deepcopy__', '__delattr__', '__delitem__', '__dict__', '__dir__', '__div__', '__divmod__', '__doc__', '__eq__', '__finalize__', '__float__', '__floordiv__', '__format__', '__ge__', '__getattr__', '__getattribute__', '__getitem__', '__getstate__', '__gt__', '__hash__', '__iadd__', '__idiv__', '__imul__', '__init__', '__int__', '__invert__', '__ipow__', '__isub__', '__iter__', '__itruediv__', '__le__', '__len__', '__long__', '__lt__', '__mod__', '__module__', '__mul__', '__ne__', '__neg__', '__new__', '__nonzero__', '__or__', '__pow__', '__radd__', '__rand__', '__rdiv__', '__reduce__', '__reduce_ex__', '__repr__', '__rfloordiv__', '__rmod__', '__rmul__', '__ror__', '__round__', '__rpow__', '__rsub__', '__rtruediv__', '__rxor__', '__setattr__', '__setitem__', '__setstate__', '__sizeof__', '__str__', '__sub__', '__subclasshook__', '__truediv__', '__unicode__', '__weakref__', '__xor__', '_accessors', '_add_numeric_operations', '_add_series_only_operations', '_add_series_or_dataframe_operations', '_agg_by_level', '_agg_doc', '_aggregate', '_aggregate_multiple_funcs', '_align_frame', '_align_series', '_allow_index_ops', '_at', '_binop', '_box_item_values', '_builtin_table', '_can_hold_na', '_check_inplace_setting', '_check_is_chained_assignment_possible', '_check_percentile', '_check_setitem_copy', '_clear_item_cache', '_clip_with_scalar', '_consolidate', '_consolidate_inplace', '_construct_axes_dict', '_construct_axes_dict_for_slice', '_construct_axes_dict_from', '_construct_axes_from_arguments', '_constructor', '_constructor_expanddim', '_constructor_sliced', '_convert', '_create_indexer', '_cython_table', '_dir_additions', '_dir_deletions', '_expand_axes', '_from_axes', '_get_axis', '_get_axis_name', '_get_axis_number', '_get_axis_resolvers', '_get_block_manager_axis', '_get_bool_data', '_get_cacher', '_get_index_resolvers', '_get_item_cache', '_get_numeric_data', '_get_values', '_get_values_tuple', '_get_with', '_gotitem', '_iat', '_iget_item_cache', '_iloc', '_index', '_indexed_same', '_info_axis', '_info_axis_name', '_info_axis_number', '_init_mgr', '_internal_names', '_internal_names_set', '_is_builtin_func', '_is_cached', '_is_cython_func', '_is_datelike_mixed_type', '_is_mixed_type', '_is_numeric_mixed_type', '_is_view', '_ix', '_ixs', '_loc', '_make_cat_accessor', '_make_dt_accessor', '_make_str_accessor', '_maybe_cache_changed', '_maybe_update_cacher', '_metadata', '_needs_reindex_multi', '_obj_with_exclusions', '_protect_consolidate', '_reduce', '_reindex_axes', '_reindex_axis', '_reindex_indexer', '_reindex_multi', '_reindex_with_indexers', '_repr_data_resource_', '_repr_latex_', '_reset_cache', '_reset_cacher', '_selected_obj', '_selection', '_selection_list', '_selection_name', '_set_as_cached', '_set_axis', '_set_axis_name', '_set_is_copy', '_set_item', '_set_labels', '_set_name', '_set_subtyp', '_set_values', '_set_with', '_set_with_engine', '_setup_axes', '_shallow_copy', '_slice', '_stat_axis', '_stat_axis_name', '_stat_axis_number', '_try_aggregate_string_function', '_typ', '_unpickle_series_compat', '_update_inplace', '_validate_dtype', '_values', '_where', '_xs', 'abs', 'add', 'add_prefix', 'add_suffix', 'agg', 'aggregate', 'align', 'all', 'any', 'append', 'apply', 'argmax', 'argmin', 'argsort', 'as_blocks', 'as_matrix', 'asfreq', 'asobject', 'asof', 'astype', 'at', 'at_time', 'autocorr', 'axes', 'base', 'between', 'between_time', 'bfill', 'blocks', 'bool', 'clip', 'clip_lower', 'clip_upper', 'combine', 'combine_first', 'compound', 'compress', 'consolidate', 'convert_objects', 'copy', 'corr', 'count', 'cov', 'cummax', 'cummin', 'cumprod', 'cumsum', 'data', 'describe', 'diff', 'div', 'divide', 'dot', 'dro ...

# %%
s.values
# Out:
# array(['one', 'two', 'three'], dtype=object)

# %%
s.index
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
s.dtype
# Out:
# dtype('O')

# %% [markdown]
# Most common Data Types:
#
#     dtype('O') --> Object
#     dtype('int64') --> Integer
#     dtype('float64') --> Float
#     dtype('bool') --> Bool

# %% [markdown]
# ### Series Methods

# %%
s = pd.Series([1.21, 1.90, 1.55])
s
# Out:
# 0    1.21
# 1    1.90
# 2    1.55
# dtype: float64

# %%
s.sum()
# Out:
# 4.6600000000000001

# %%
s.product()
# Out:
# 3.56345

# %%
s.mean()
# Out:
# 1.5533333333333335

# %% [markdown]
# Create new Series giving a custom **INDEX** list.

# %%
colors_list = ["red", "blue", "green", "yellow"]
numbers = ["one", "two", "three", "four"]

# pd.Series(colors_list, numbers) 
# pd.Series(colors_list, index=numbers) 
pd.Series(data=colors_list, index=numbers)
# Out:
# one         red
# two        blue
# three     green
# four     yellow
# dtype: object

# %% [markdown]
# We can duplicate **INDEXES**.

# %%
colors_list = ["red", "blue", "green", "yellow"]
numbers = ["one", "one", "one", "one"]

# pd.Series(colors_list, numbers) 
# pd.Series(colors_list, index=numbers) 
pd.Series(data=colors_list, index=numbers)
# Out:
# one       red
# one      blue
# one     green
# one    yellow
# dtype: object

# %% [markdown]
# ### Series - Other Attributes

# %%
s = pd.Series(colors_list)
s
# Out:
# 0       red
# 1      blue
# 2     green
# 3    yellow
# dtype: object

# %%
s.is_unique
# Out:
# True

# %%
pd.Series([1,1]).is_unique
#pd.Series([1]).is_unique
# Out:
# False

# %%
# Series Dimension
s.shape
# Out:
# (4,)

# %%
print s.name
s = pd.Series(colors_list, name="Hello")
print s.name
print s
# Out:
# None
# Hello
# 0       red
# 1      blue
# 2     green
# 3    yellow
# Name: Hello, dtype: object

# %% [markdown]
# ### sort_values
#
# Order by Values

# %%
s.sort_values()
# Out:
# 1      blue
# 2     green
# 0       red
# 3    yellow
# Name: Hello, dtype: object

# %%
print s.sort_values(ascending=False)
print s
# Out:
# 3    yellow
# 0       red
# 2     green
# 1      blue
# Name: Hello, dtype: object
# 0       red
# 1      blue
# 2     green
# 3    yellow
# Name: Hello, dtype: object

# %% [markdown]
# ### inplace
#
# Used to override the original object

# %%
print s.sort_values(ascending=False, inplace=True)
print s
# Out:
# None
# 3    yellow
# 0       red
# 2     green
# 1      blue
# Name: Hello, dtype: object

# %% [markdown]
# ### sort_index
#
# Order by Index

# %%
s.sort_index()
# Out:
# 0       red
# 1      blue
# 2     green
# 3    yellow
# Name: Hello, dtype: object

# %%
s.sort_index(ascending=False)
# Out:
# 3    yellow
# 2     green
# 1      blue
# 0       red
# Name: Hello, dtype: object

# %%
s.sort_index(inplace=True)
s
# Out:
# 0       red
# 1      blue
# 2     green
# 3    yellow
# Name: Hello, dtype: object

# %% [markdown]
# ### IN Keyword

# %%
s = pd.Series(colors_list)
'red' in s.values
# Out:
# True

# %%
0 in s
0 in s.index
# Out:
# True

# %% [markdown]
# ### Get Values By Index

# %%
s[0]
# Out:
# 'red'

# %%
print s.get(0)
s.get(23424234, default='NON ESISTE')
# Out:
# red
# 'NON ESISTE'

# %%
s.get_value(0)
# Out:
# 'red'

# %%
# Get by multiple indexes
s[ [0,1,2] ]
# Out:
# 0      red
# 1     blue
# 2    green
# dtype: object

# %%
s[[0,2]]
# Out:
# 0      red
# 2    green
# dtype: object

# %%
s[0:3]
# Out:
# 0      red
# 1     blue
# 2    green
# dtype: object

# %%
s.get([0,2])
# Out:
# 0      red
# 2    green
# dtype: object

# %%
print s.get(199)
# s[199]
# Out:
# None

# %%
s.get(199, default="Not Found")
# Out:
# 'Not Found'

# %%
ciao = s.get([1,100], default="You can't see me")
print ciao
s
# Out:
# 1      blue
# 100     NaN
# dtype: object
# 0       red
# 1      blue
# 2     green
# 3    yellow
# dtype: object

# %% [markdown]
# ### Math Methods

# %%
s = pd.Series([1.21, 1.90, 1.55, 1.98, 4.4, 8.54, 1.21])
s
# Out:
# 0    1.21
# 1    1.90
# 2    1.55
# 3    1.98
# 4    4.40
# 5    8.54
# 6    1.21
# dtype: float64

# %%
s.count()
# Out:
# 7

# %%
len(s)
# Out:
# 7

# %%
print s.sum()
print s.mean()
print s.product()
print s.max()
print s.median()
print s.mode()
print '---'
print s.describe()
# Out:
# 20.79
# 2.97
# 320.798092452
# 8.54
# 1.9
# 0    1.21
# dtype: float64
# ---
# count    7.000000
# mean     2.970000
# std      2.689684
# min      1.210000
# 25%      1.380000
# 50%      1.900000
# 75%      3.190000
# max      8.540000
# dtype: float64

# %% [markdown]
# ### idxmax & idxmin

# %%
# Get value at index MAX
print s
index = s.idxmax()
print index, s.get(index)
# Out:
# 0    1.21
# 1    1.90
# 2    1.55
# 3    1.98
# 4    4.40
# 5    8.54
# 6    1.21
# dtype: float64
# 5 8.54

# %%
# Get value at index MIN
index = s.idxmin()
print index, s.get(index)
# Out:
# 0 1.21

# %% [markdown]
# ### value_counts

# %%
s = pd.Series(data=["Alex", "Pippo", "Vale", "Alex", "Hello"])

# %%
# Get occurrences for each value
s.value_counts()
# Out:
# Alex     2
# Vale     1
# Hello    1
# Pippo    1
# dtype: int64

# %%
type(s.value_counts().sum())
# Out:
# numpy.int64

# %%
s.count() == s.value_counts().sum()
# Out:
# True

# %%
s.value_counts(ascending=True)
# Out:
# Pippo    1
# Hello    1
# Vale     1
# Alex     2
# dtype: int64

# %% [markdown]
# ### Apply
#
# Apply custom function on each element of the Serie

# %%
s = pd.Series([1.21, 1.90, 1.55, 1.98, 4.4, 8.54, 1.21])
s
# Out:
# 0    1.21
# 1    1.90
# 2    1.55
# 3    1.98
# 4    4.40
# 5    8.54
# 6    1.21
# dtype: float64

# %%
def get_something(number):
    if number <4:
        return 'OOOOH!!'
    return 'AAAAAHHHH!'

# %%
s.apply(get_something)
# Out:
# 0       OOOOH!!
# 1       OOOOH!!
# 2       OOOOH!!
# 3       OOOOH!!
# 4    AAAAAHHHH!
# 5    AAAAAHHHH!
# 6       OOOOH!!
# dtype: object

# %%
s.apply(lambda x: "{}$".format(x))
# Out:
# 0    1.21$
# 1     1.9$
# 2    1.55$
# 3    1.98$
# 4     4.4$
# 5    8.54$
# 6    1.21$
# dtype: object

# %% [markdown]
# ### map
#
# Map for each element

# %%
s = pd.Series(data=["Alex", "Pippo", "Vale", "Hello"])
s
# Out:
# 0     Alex
# 1    Pippo
# 2     Vale
# 3    Hello
# dtype: object

# %%
s2 = pd.Series(data=["Comu", "Pippini", "Gela", "World"], 
               index=["Alex", "Pippo", "Vale", "Hello"])
s2
# Out:
# Alex        Comu
# Pippo    Pippini
# Vale        Gela
# Hello      World
# dtype: object

# %%
s.map(s2)
# Out:
# 0       Comu
# 1    Pippini
# 2       Gela
# 3      World
# dtype: object

# %%
s2_dict = s2.to_dict()

# %%
s2_dict
# Out:
# {'Alex': 'Comu', 'Hello': 'World', 'Pippo': 'Pippini', 'Vale': 'Gela'}

# %%
s.map(s2_dict)
# Out:
# 0       Comu
# 1    Pippini
# 2       Gela
# 3      World
# dtype: object

# %% [markdown]
# ## Load data from CSV

# %%
s = pd.read_csv('dataset/speedtest.csv', 
                usecols=['CLIENT_CITY'],
                squeeze=True)

# %%
print type(s)
# Out:
# <class 'pandas.core.series.Series'>

# %%
s
# Out:
# 0          Bardonecchia
# 1                 Turin
# 2          Bardonecchia
# 3          Bardonecchia
# 4          Bardonecchia
# 5          Bardonecchia
# 6          Bardonecchia
# 7                 Turin
# 8              Aramengo
# 9                 Turin
# 10                Turin
# 11                Turin
# 12                Turin
# 13                Turin
# 14              Imperia
# 15                Turin
# 16              Imperia
# 17               Almese
# 18               Almese
# 19                Turin
# 20              Bibiana
# 21         Bardonecchia
# 22         Bardonecchia
# 23                Turin
# 24                 Asti
# 25                Turin
# 26                Turin
# 27                Turin
# 28                 Asti
# 29                Turin
#               ...
# 199114            Turin
# 199115            Turin
# 199116    Bene Vagienna
# 199117            Turin
# 199118            Turin
# 199119            Turin
# 199120            Turin
# 199121            Turin
# 199122            Turin
# 199123            Turin
# 199124          Bangkok
# 199125            Turin
# 199126           Novara
# 199127            Turin
# 199128            Turin
# 199129            Turin
# 199130           Almese
# 199131              NaN
# 199132           Rivoli
# 199133           Rivoli
# 199134              NaN
# 199135           Almese
# 199136           Rivoli
# 199137        Scalenghe
# 199138            Turin
# 199139       Pettenasco
# 199140         Florence
# 199141            Turin
# 199142            Turin
# 199143            Turin
# Name: CLIENT_CITY, Length: 199144, dtype: object

# %%
s.index
# Out:
# RangeIndex(start=0, stop=199144, step=1)

# %%
s.tail()
# Out:
# 199139    Pettenasco
# 199140      Florence
# 199141         Turin
# 199142         Turin
# 199143         Turin
# Name: CLIENT_CITY, dtype: object

# %%
list(s)
# Out:
# ['Bardonecchia',
#  'Turin',
#  'Bardonecchia',
#  'Bardonecchia',
#  'Bardonecchia',
#  'Bardonecchia',
#  'Bardonecchia',
#  'Turin',
#  'Aramengo',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Imperia',
#  'Turin',
#  'Imperia',
#  'Almese',
#  'Almese',
#  'Turin',
#  'Bibiana',
#  'Bardonecchia',
#  'Bardonecchia',
#  'Turin',
#  'Asti',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Asti',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Varese',
#  'Aosta',
#  'Asti',
#  nan,
#  'Alessandria',
#  'Turin',
#  'Turin',
#  'Giarole',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Casale Monferrato',
#  'Casale Monferrato',
#  'Turin',
#  'Turin',
#  'Rubiana',
#  'Rubiana',
#  'Turin',
#  'Turin',
#  nan,
#  'Turin',
#  'Turin',
#  'Turin',
#  'Asti',
#  'Asti',
#  'Turin',
#  'Casale Monferrato',
#  'Airasca',
#  'Casale Monferrato',
#  nan,
#  'Casale Monferrato',
#  'Turin',
#  'Casale Monferrato',
#  'Turin',
#  'Valpelline',
#  'Casale Monferrato',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Airasca',
#  'Pessinetto',
#  'Turin',
#  'Alessandria',
#  'Alessandria',
#  'Pessinetto',
#  'Turin',
#  nan,
#  'Turin',
#  'Calamandrana',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Almese',
#  'Almese',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Milan',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Milan',
#  'Turin',
#  'Turin',
#  'Cocconato',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Cocconato',
#  'Turin',
#  'Tronzano Vercellese',
#  'Biella',
#  'Turin',
#  'Bra',
#  'Almese',
#  'Almese',
#  'Turin',
#  'Ala Di Stura',
#  'Turin',
#  'Turin',
#  'Cocconato',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Grugliasco',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Milan',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Rubiana',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Grugliasco',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Vercelli',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Novara',
#  'Turin',
#  'Oleggio',
#  'Turin',
#  'Rivoli',
#  'Ala Di Stura',
#  'Turin',
#  'Rivoli',
#  'Saluzzo',
#  'Turin',
#  'Montepaone',
#  'Turin',
#  'Casale Monferrato',
#  'Turin',
#  'Pinerolo',
#  'Turin',
#  'Piscina',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Casale Monferrato',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Nichelino',
#  'Ivrea',
#  nan,
#  'Aramengo',
#  'Valenza',
#  'Ghemme',
#  'Turin',
#  'Turin',
#  'Vercelli',
#  'Almese',
#  'Turin',
#  'Mestre',
#  'Turin',
#  'Beinette',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Turin',
#  nan,
#  'Perosa Argentina',
#  'Vallecrosia',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Roccabruna',
#  'Turin',
#  'Alba',
#  'Turin',
#  'Almese',
#  'Bergamo',
#  'Turin',
#  'Turin',
#  'Bardonecchia',
#  'Asti',
#  'Almese',
#  'Cravanzana',
#  'Almese',
#  'Casale Monferrato',
#  'Biella',
#  'Casale Monferrato',
#  'Almese',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Biella',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Casale Monferrato',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Bardonecchia',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Milan',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Casale Monferrato',
#  'San Gillio',
#  'Bardonecchia',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Casale Monferrato',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Turin',
#  'San Gillio',
#  'Turin',
#  'Borgaro Torinese',
#  'Borgaro Torinese',
#  'Turin',
#  'Casale Monferrato',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Casale Monferrato',
#  'Giaveno',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Almese',
#  'Andezeno',
#  'Novara',
#  'Casale Monferrato',
#  'Turin',
#  'Ivrea',
#  'Grugliasco',
#  'Santo Stefano Belbo',
#  'Limone Piemonte',
#  'Turin',
#  'Turin',
#  'Casale Monferrato',
#  'Pratiglione',
#  'Turin',
#  'Turin',
#  'Vercelli',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Caluso',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Turin',
#  "San Damiano D'asti",
#  'Almese',
#  'Turin',
#  'Casale Monferrato',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Casale Monferrato',
#  'Turin',
#  'Turin',
#  'Aramengo',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Casale Monferrato',
#  'Turin',
#  'Turin',
#  'Casale Monferrato',
#  'Pocapaglia',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Perosa Argentina',
#  'Parma',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Asti',
#  'Turin',
#  'Cuneo',
#  'Almese',
#  'Almese',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Alessandria',
#  'Cocconato',
#  'Alessandria',
#  'Imperia',
#  'Caluso',
#  'Rubiana',
#  'Alessandria',
#  'Turin',
#  'Turin',
#  'Alessandria',
#  'Turin',
#  'Moncalieri',
#  'Turin',
#  'Turin',
#  'Chivasso',
#  'Turin',
#  'Cerrione',
#  'Salussola',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Rome',
#  'Turin',
#  'Andezeno',
#  'Centallo',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Bruino',
#  'Turin',
#  'Novara',
#  'Turin',
#  'Rivoli',
#  'Genova',
#  'Turin',
#  'Genova',
#  'Asti',
#  'Agli\xc3\xa8',
#  'Turin',
#  'Turin',
#  'Biella',
#  'Turin',
#  'Casale Monferrato',
#  'Legnano',
#  'Legnano',
#  'Legnano',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Casale Monferrato',
#  'Turin',
#  'Alessandria',
#  'Turin',
#  'Casale Monferrato',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Poggio Rusco',
#  'Turin',
#  'Turin',
#  'Poggio Rusco',
#  'Rubiana',
#  'Turin',
#  'Bruino',
#  'Turin',
#  'Rubiana',
#  'Rivoli',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Saluzzo',
#  'Cocconato',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Rubiana',
#  'Cravanzana',
#  'Cravanzana',
#  'Almese',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Cuneo',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Andezeno',
#  'Borgo San Martino',
#  'Turin',
#  'Andezeno',
#  'Turin',
#  'Andezeno',
#  'Turin',
#  'Turin',
#  'Vercelli',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Milano',
#  'Borgo San Martino',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Gavi',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Turin',
#  'San Gillio',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Andezeno',
#  'Turin',
#  'Turin',
#  'Rubiana',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Valfenera',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Rome',
#  'Milan',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Cuneo',
#  'Rubiana',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Rubiana',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Cassinelle',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Rubiana',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Cesana Torinese',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Cesana Torinese',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Alpette',
#  'Montemagno',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Avigliana',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Rubiana',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Marcallo Con Casone',
#  'Rubiana',
#  nan,
#  'Turin',
#  'Turin',
#  'Vercelli',
#  'Turin',
#  'Grugliasco',
#  'Marcallo Con Casone',
#  'Turin',
#  'Turin',
#  'Roccabruna',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Vercelli',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Novara',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Rubiana',
#  'Perosa Argentina',
#  'Cuneo',
#  'Turin',
#  'Cuneo',
#  'Turin',
#  'Airasca',
#  'Cuneo',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Treviso',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Airasca',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Vercelli',
#  'Rubiana',
#  'Antey-saint-andr\xc3\xa9',
#  'Milano',
#  'Turin',
#  'Busca',
#  'Rubiana',
#  'Turin',
#  'Turin',
#  'Busca',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Rubiana',
#  'Airasca',
#  'Turin',
#  'Turin',
#  'Ghemme',
#  'Rivoli',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Genova',
#  'Milan',
#  'Turin',
#  'Turin',
#  'Naples',
#  'Turin',
#  'Borgo Vercelli',
#  nan,
#  'Turin',
#  'Turin',
#  'Turin',
#  'Busca',
#  'Turin',
#  'Busca',
#  'Asti',
#  'Turin',
#  'Turin',
#  'Rubiana',
#  'Montichiari',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Turin',
#  'San Salvatore Monferrato',
#  'Turin',
#  'Turin',
#  'Collegno',
#  'Bruino',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Piscina',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Cusano Milanino',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Luserna San Giovanni',
#  'Albignasego',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Collegno',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Collegno',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Rome',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Turin',
#  "Villafranca D'asti",
#  'Turin',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Turin',
#  'La Magdeleine',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Rubiana',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Milan',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Brusasco',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Asti',
#  'Biella',
#  'Turin',
#  'Almese',
#  'Turin',
#  'Niella Tanaro',
#  'Sommariva Perno',
#  'Turin',
#  'Gerbido',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Collegno',
#  nan,
#  'Turin',
#  'Turin',
#  'Bene Vagienna',
#  'Nichelino',
#  'Turin',
#  'Rubiana',
#  'Turin',
#  'Almese',
#  'Rubiana',
#  'Turin',
#  'Turin',
#  'Sommariva Perno',
#  'Turin',
#  'Cinisello Balsamo',
#  'Agli\xc3\xa8',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Rubiana',
#  'Turin',
#  'Rivoli',
#  'Salassa',
#  'Turin',
#  'Turin',
#  'Bardonecchia',
#  'Turin',
#  'Turin',
#  'Aramengo',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Cravanzana',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Imperia',
#  'Imperia',
#  'Cumiana',
#  'Turin',
#  'Turin',
#  'Caluso',
#  nan,
#  'Imperia',
#  'Novara',
#  'Grugliasco',
#  'Roccabruna',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Varallo Pombia',
#  'Asti',
#  'Turin',
#  'Turin',
#  'Imperia',
#  'Turin',
#  'Imperia',
#  'Imperia',
#  'Turin',
#  'Santena',
#  'Nichelino',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Nichelino',
#  'Turin',
#  'Turin',
#  'Cagnes-sur-mer',
#  'Turin',
#  'Turin',
#  'Turin',
#  'San Salvatore Monferrato',
#  'Airasca',
#  'San Salvatore Monferrato',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Asti',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Sangano',
#  'Turin',
#  'Rocca Canavese',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Bruino',
#  'Moncalieri',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Alba',
#  'Turin',
#  'Turin',
#  'Nichelino',
#  'Nichelino',
#  'Turin',
#  'Turin',
#  'Alba',
#  'Magliano Alpi',
#  'Turin',
#  'Nichelino',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Andezeno',
#  'Turin',
#  'Villastellone',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Andezeno',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Poggio Rusco',
#  'Bardonecchia',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Barge',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Forno Canavese',
#  'Forno Canavese',
#  'Novara',
#  'Turin',
#  'Turin',
#  'Caluso',
#  'Turin',
#  'Grugliasco',
#  'Bardonecchia',
#  'Fossano',
#  'Pinerolo',
#  'Borgaro Torinese',
#  'Turin',
#  'Cocconato',
#  'Trofarello',
#  'Ala Di Stura',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Turin',
#  'Vercelli',
#  'Turin',
#  'Vetulonia',
#  ...]

# %%
dict(s)
# Out:
# {0: 'Bardonecchia',
#  1: 'Turin',
#  2: 'Bardonecchia',
#  3: 'Bardonecchia',
#  4: 'Bardonecchia',
#  5: 'Bardonecchia',
#  6: 'Bardonecchia',
#  7: 'Turin',
#  8: 'Aramengo',
#  9: 'Turin',
#  10: 'Turin',
#  11: 'Turin',
#  12: 'Turin',
#  13: 'Turin',
#  14: 'Imperia',
#  15: 'Turin',
#  16: 'Imperia',
#  17: 'Almese',
#  18: 'Almese',
#  19: 'Turin',
#  20: 'Bibiana',
#  21: 'Bardonecchia',
#  22: 'Bardonecchia',
#  23: 'Turin',
#  24: 'Asti',
#  25: 'Turin',
#  26: 'Turin',
#  27: 'Turin',
#  28: 'Asti',
#  29: 'Turin',
#  30: 'Turin',
#  31: 'Turin',
#  32: 'Turin',
#  33: 'Varese',
#  34: 'Aosta',
#  35: 'Asti',
#  36: nan,
#  37: 'Alessandria',
#  38: 'Turin',
#  39: 'Turin',
#  40: 'Giarole',
#  41: 'Turin',
#  42: 'Turin',
#  43: 'Turin',
#  44: 'Turin',
#  45: 'Turin',
#  46: 'Casale Monferrato',
#  47: 'Casale Monferrato',
#  48: 'Turin',
#  49: 'Turin',
#  50: 'Rubiana',
#  51: 'Rubiana',
#  52: 'Turin',
#  53: 'Turin',
#  54: nan,
#  55: 'Turin',
#  56: 'Turin',
#  57: 'Turin',
#  58: 'Asti',
#  59: 'Asti',
#  60: 'Turin',
#  61: 'Casale Monferrato',
#  62: 'Airasca',
#  63: 'Casale Monferrato',
#  64: nan,
#  65: 'Casale Monferrato',
#  66: 'Turin',
#  67: 'Casale Monferrato',
#  68: 'Turin',
#  69: 'Valpelline',
#  70: 'Casale Monferrato',
#  71: 'Turin',
#  72: 'Turin',
#  73: 'Turin',
#  74: 'Airasca',
#  75: 'Pessinetto',
#  76: 'Turin',
#  77: 'Alessandria',
#  78: 'Alessandria',
#  79: 'Pessinetto',
#  80: 'Turin',
#  81: nan,
#  82: 'Turin',
#  83: 'Calamandrana',
#  84: 'Turin',
#  85: 'Turin',
#  86: 'Turin',
#  87: 'Almese',
#  88: 'Almese',
#  89: 'Turin',
#  90: 'Turin',
#  91: 'Turin',
#  92: 'Milan',
#  93: 'Turin',
#  94: 'Turin',
#  95: 'Turin',
#  96: 'Turin',
#  97: 'Turin',
#  98: 'Turin',
#  99: 'Milan',
#  100: 'Turin',
#  101: 'Turin',
#  102: 'Cocconato',
#  103: 'Turin',
#  104: 'Turin',
#  105: 'Turin',
#  106: 'Cocconato',
#  107: 'Turin',
#  108: 'Tronzano Vercellese',
#  109: 'Biella',
#  110: 'Turin',
#  111: 'Bra',
#  112: 'Almese',
#  113: 'Almese',
#  114: 'Turin',
#  115: 'Ala Di Stura',
#  116: 'Turin',
#  117: 'Turin',
#  118: 'Cocconato',
#  119: 'Turin',
#  120: 'Turin',
#  121: 'Turin',
#  122: 'Grugliasco',
#  123: 'Turin',
#  124: 'Turin',
#  125: 'Turin',
#  126: 'Milan',
#  127: 'Turin',
#  128: 'Turin',
#  129: 'Turin',
#  130: 'Turin',
#  131: 'Turin',
#  132: 'Turin',
#  133: 'Turin',
#  134: 'Rubiana',
#  135: 'Turin',
#  136: 'Turin',
#  137: 'Turin',
#  138: 'Turin',
#  139: 'Turin',
#  140: 'Turin',
#  141: 'Grugliasco',
#  142: 'Turin',
#  143: 'Turin',
#  144: 'Turin',
#  145: 'Vercelli',
#  146: 'Turin',
#  147: 'Turin',
#  148: 'Turin',
#  149: 'Novara',
#  150: 'Turin',
#  151: 'Oleggio',
#  152: 'Turin',
#  153: 'Rivoli',
#  154: 'Ala Di Stura',
#  155: 'Turin',
#  156: 'Rivoli',
#  157: 'Saluzzo',
#  158: 'Turin',
#  159: 'Montepaone',
#  160: 'Turin',
#  161: 'Casale Monferrato',
#  162: 'Turin',
#  163: 'Pinerolo',
#  164: 'Turin',
#  165: 'Piscina',
#  166: 'Turin',
#  167: 'Turin',
#  168: 'Turin',
#  169: 'Turin',
#  170: 'Turin',
#  171: 'Casale Monferrato',
#  172: 'Turin',
#  173: 'Turin',
#  174: 'Turin',
#  175: 'Turin',
#  176: 'Turin',
#  177: 'Turin',
#  178: 'Turin',
#  179: 'Turin',
#  180: 'Nichelino',
#  181: 'Ivrea',
#  182: nan,
#  183: 'Aramengo',
#  184: 'Valenza',
#  185: 'Ghemme',
#  186: 'Turin',
#  187: 'Turin',
#  188: 'Vercelli',
#  189: 'Almese',
#  190: 'Turin',
#  191: 'Mestre',
#  192: 'Turin',
#  193: 'Beinette',
#  194: 'Turin',
#  195: 'Turin',
#  196: 'Turin',
#  197: 'Turin',
#  198: 'Turin',
#  199: nan,
#  200: 'Perosa Argentina',
#  201: 'Vallecrosia',
#  202: 'Turin',
#  203: 'Turin',
#  204: 'Turin',
#  205: 'Roccabruna',
#  206: 'Turin',
#  207: 'Alba',
#  208: 'Turin',
#  209: 'Almese',
#  210: 'Bergamo',
#  211: 'Turin',
#  212: 'Turin',
#  213: 'Bardonecchia',
#  214: 'Asti',
#  215: 'Almese',
#  216: 'Cravanzana',
#  217: 'Almese',
#  218: 'Casale Monferrato',
#  219: 'Biella',
#  220: 'Casale Monferrato',
#  221: 'Almese',
#  222: 'Turin',
#  223: 'Turin',
#  224: 'Turin',
#  225: 'Turin',
#  226: 'Turin',
#  227: 'Turin',
#  228: 'Turin',
#  229: 'Turin',
#  230: 'Turin',
#  231: 'Turin',
#  232: 'Biella',
#  233: 'Turin',
#  234: 'Turin',
#  235: 'Turin',
#  236: 'Turin',
#  237: 'Casale Monferrato',
#  238: 'Turin',
#  239: 'Turin',
#  240: 'Turin',
#  241: 'Bardonecchia',
#  242: 'Turin',
#  243: 'Turin',
#  244: 'Turin',
#  245: 'Milan',
#  246: 'Turin',
#  247: 'Turin',
#  248: 'Turin',
#  249: 'Casale Monferrato',
#  250: 'San Gillio',
#  251: 'Bardonecchia',
#  252: 'Turin',
#  253: 'Turin',
#  254: 'Turin',
#  255: 'Casale Monferrato',
#  256: 'Turin',
#  257: 'Turin',
#  258: 'Turin',
#  259: 'Turin',
#  260: 'Turin',
#  261: 'San Gillio',
#  262: 'Turin',
#  263: 'Borgaro Torinese',
#  264: 'Borgaro Torinese',
#  265: 'Turin',
#  266: 'Casale Monferrato',
#  267: 'Turin',
#  268: 'Turin',
#  269: 'Turin',
#  270: 'Turin',
#  271: 'Turin',
#  272: 'Turin',
#  273: 'Turin',
#  274: 'Turin',
#  275: 'Casale Monferrato',
#  276: 'Giaveno',
#  277: 'Turin',
#  278: 'Turin',
#  279: 'Turin',
#  280: 'Almese',
#  281: 'Andezeno',
#  282: 'Novara',
#  283: 'Casale Monferrato',
#  284: 'Turin',
#  285: 'Ivrea',
#  286: 'Grugliasco',
#  287: 'Santo Stefano Belbo',
#  288: 'Limone Piemonte',
#  289: 'Turin',
#  290: 'Turin',
#  291: 'Casale Monferrato',
#  292: 'Pratiglione',
#  293: 'Turin',
#  294: 'Turin',
#  295: 'Vercelli',
#  296: 'Turin',
#  297: 'Turin',
#  298: 'Turin',
#  299: 'Turin',
#  300: 'Turin',
#  301: 'Caluso',
#  302: 'Turin',
#  303: 'Turin',
#  304: 'Turin',
#  305: 'Turin',
#  306: 'Turin',
#  307: "San Damiano D'asti",
#  308: 'Almese',
#  309: 'Turin',
#  310: 'Casale Monferrato',
#  311: 'Turin',
#  312: 'Turin',
#  313: 'Turin',
#  314: 'Turin',
#  315: 'Turin',
#  316: 'Turin',
#  317: 'Turin',
#  318: 'Turin',
#  319: 'Turin',
#  320: 'Casale Monferrato',
#  321: 'Turin',
#  322: 'Turin',
#  323: 'Aramengo',
#  324: 'Turin',
#  325: 'Turin',
#  326: 'Turin',
#  327: 'Casale Monferrato',
#  328: 'Turin',
#  329: 'Turin',
#  330: 'Casale Monferrato',
#  331: 'Pocapaglia',
#  332: 'Turin',
#  333: 'Turin',
#  334: 'Turin',
#  335: 'Turin',
#  336: 'Turin',
#  337: 'Turin',
#  338: 'Turin',
#  339: 'Turin',
#  340: 'Perosa Argentina',
#  341: 'Parma',
#  342: 'Turin',
#  343: 'Turin',
#  344: 'Turin',
#  345: 'Turin',
#  346: 'Turin',
#  347: 'Asti',
#  348: 'Turin',
#  349: 'Cuneo',
#  350: 'Almese',
#  351: 'Almese',
#  352: 'Turin',
#  353: 'Turin',
#  354: 'Turin',
#  355: 'Turin',
#  356: 'Turin',
#  357: 'Turin',
#  358: 'Turin',
#  359: 'Turin',
#  360: 'Turin',
#  361: 'Turin',
#  362: 'Turin',
#  363: 'Turin',
#  364: 'Alessandria',
#  365: 'Cocconato',
#  366: 'Alessandria',
#  367: 'Imperia',
#  368: 'Caluso',
#  369: 'Rubiana',
#  370: 'Alessandria',
#  371: 'Turin',
#  372: 'Turin',
#  373: 'Alessandria',
#  374: 'Turin',
#  375: 'Moncalieri',
#  376: 'Turin',
#  377: 'Turin',
#  378: 'Chivasso',
#  379: 'Turin',
#  380: 'Cerrione',
#  381: 'Salussola',
#  382: 'Turin',
#  383: 'Turin',
#  384: 'Turin',
#  385: 'Turin',
#  386: 'Turin',
#  387: 'Turin',
#  388: 'Turin',
#  389: 'Turin',
#  390: 'Rome',
#  391: 'Turin',
#  392: 'Andezeno',
#  393: 'Centallo',
#  394: 'Turin',
#  395: 'Turin',
#  396: 'Turin',
#  397: 'Turin',
#  398: 'Turin',
#  399: 'Turin',
#  400: 'Turin',
#  401: 'Bruino',
#  402: 'Turin',
#  403: 'Novara',
#  404: 'Turin',
#  405: 'Rivoli',
#  406: 'Genova',
#  407: 'Turin',
#  408: 'Genova',
#  409: 'Asti',
#  410: 'Agli\xc3\xa8',
#  411: 'Turin',
#  412: 'Turin',
#  413: 'Biella',
#  414: 'Turin',
#  415: 'Casale Monferrato',
#  416: 'Legnano',
#  417: 'Legnano',
#  418: 'Legnano',
#  419: 'Turin',
#  420: 'Turin',
#  421: 'Turin',
#  422: 'Turin',
#  423: 'Turin',
#  424: 'Casale Monferrato',
#  425: 'Turin',
#  426: 'Alessandria',
#  427: 'Turin',
#  428: 'Casale Monferrato',
#  429: 'Turin',
#  430: 'Turin',
#  431: 'Turin',
#  432: 'Turin',
#  433: 'Poggio Rusco',
#  434: 'Turin',
#  435: 'Turin',
#  436: 'Poggio Rusco',
#  437: 'Rubiana',
#  438: 'Turin',
#  439: 'Bruino',
#  440: 'Turin',
#  441: 'Rubiana',
#  442: 'Rivoli',
#  443: 'Turin',
#  444: 'Turin',
#  445: 'Turin',
#  446: 'Saluzzo',
#  447: 'Cocconato',
#  448: 'Turin',
#  449: 'Turin',
#  450: 'Turin',
#  451: 'Turin',
#  452: 'Turin',
#  453: 'Turin',
#  454: 'Rubiana',
#  455: 'Cravanzana',
#  456: 'Cravanzana',
#  457: 'Almese',
#  458: 'Turin',
#  459: 'Turin',
#  460: 'Turin',
#  461: 'Turin',
#  462: 'Turin',
#  463: 'Turin',
#  464: 'Cuneo',
#  465: 'Turin',
#  466: 'Turin',
#  467: 'Turin',
#  468: 'Turin',
#  469: 'Turin',
#  470: 'Turin',
#  471: 'Turin',
#  472: 'Turin',
#  473: 'Turin',
#  474: 'Turin',
#  475: 'Andezeno',
#  476: 'Borgo San Martino',
#  477: 'Turin',
#  478: 'Andezeno',
#  479: 'Turin',
#  480: 'Andezeno',
#  481: 'Turin',
#  482: 'Turin',
#  483: 'Vercelli',
#  484: 'Turin',
#  485: 'Turin',
#  486: 'Turin',
#  487: 'Turin',
#  488: 'Turin',
#  489: 'Milano',
#  490: 'Borgo San Martino',
#  491: 'Turin',
#  492: 'Turin',
#  493: 'Turin',
#  494: 'Turin',
#  495: 'Turin',
#  496: 'Turin',
#  497: 'Gavi',
#  498: 'Turin',
#  499: 'Turin',
#  500: 'Turin',
#  501: 'Turin',
#  502: 'Turin',
#  503: 'Turin',
#  504: 'Turin',
#  505: 'Turin',
#  506: 'Turin',
#  507: 'San Gillio',
#  508: 'Turin',
#  509: 'Turin',
#  510: 'Turin',
#  511: 'Turin',
#  512: 'Andezeno',
#  513: 'Turin',
#  514: 'Turin',
#  515: 'Rubiana',
#  516: 'Turin',
#  517: 'Turin',
#  518: 'Turin',
#  519: 'Turin',
#  520: 'Turin',
#  521: 'Valfenera',
#  522: 'Turin',
#  523: 'Turin',
#  524: 'Turin',
#  525: 'Rome',
#  526: 'Milan',
#  527: 'Turin',
#  528: 'Turin',
#  529: 'Turin',
#  530: 'Cuneo',
#  531: 'Rubiana',
#  532: 'Turin',
#  533: 'Turin',
#  534: 'Turin',
#  535: 'Turin',
#  536: 'Turin',
#  537: 'Turin',
#  538: 'Rubiana',
#  539: 'Turin',
#  540: 'Turin',
#  541: 'Turin',
#  542: 'Turin',
#  543: 'Turin',
#  544: 'Cassinelle',
#  545: 'Turin',
#  546: 'Turin',
#  547: 'Turin',
#  548: 'Turin',
#  549: 'Turin',
#  550: 'Turin',
#  551: 'Turin',
#  552: 'Turin',
#  553: 'Turin',
#  554: 'Turin',
#  555: 'Turin',
#  556: 'Turin',
#  557: 'Turin',
#  558: 'Rubiana',
#  559: 'Turin',
#  560: 'Turin',
#  561: 'Turin',
#  562: 'Cesana Torinese',
#  563: 'Turin',
#  564: 'Turin',
#  565: 'Turin',
#  566: 'Turin',
#  567: 'Cesana Torinese',
#  568: 'Turin',
#  569: 'Turin',
#  570: 'Turin',
#  571: 'Turin',
#  572: 'Turin',
#  573: 'Turin',
#  574: 'Turin',
#  575: 'Turin',
#  576: 'Turin',
#  577: 'Alpette',
#  578: 'Montemagno',
#  579: 'Turin',
#  580: 'Turin',
#  581: 'Turin',
#  582: 'Turin',
#  583: 'Turin',
#  584: 'Turin',
#  585: 'Turin',
#  586: 'Turin',
#  587: 'Turin',
#  588: 'Turin',
#  589: 'Turin',
#  590: 'Turin',
#  591: 'Turin',
#  592: 'Turin',
#  593: 'Turin',
#  594: 'Turin',
#  595: 'Turin',
#  596: 'Avigliana',
#  597: 'Turin',
#  598: 'Turin',
#  599: 'Turin',
#  600: 'Turin',
#  601: 'Turin',
#  602: 'Rubiana',
#  603: 'Turin',
#  604: 'Turin',
#  605: 'Turin',
#  606: 'Marcallo Con Casone',
#  607: 'Rubiana',
#  608: nan,
#  609: 'Turin',
#  610: 'Turin',
#  611: 'Vercelli',
#  612: 'Turin',
#  613: 'Grugliasco',
#  614: 'Marcallo Con Casone',
#  615: 'Turin',
#  616: 'Turin',
#  617: 'Roccabruna',
#  618: 'Turin',
#  619: 'Turin',
#  620: 'Turin',
#  621: 'Turin',
#  622: 'Turin',
#  623: 'Vercelli',
#  624: 'Turin',
#  625: 'Turin',
#  626: 'Turin',
#  627: 'Novara',
#  628: 'Turin',
#  629: 'Turin',
#  630: 'Turin',
#  631: 'Rubiana',
#  632: 'Perosa Argentina',
#  633: 'Cuneo',
#  634: 'Turin',
#  635: 'Cuneo',
#  636: 'Turin',
#  637: 'Airasca',
#  638: 'Cuneo',
#  639: 'Turin',
#  640: 'Turin',
#  641: 'Turin',
#  642: 'Treviso',
#  643: 'Turin',
#  644: 'Turin',
#  645: 'Turin',
#  646: 'Turin',
#  647: 'Turin',
#  648: 'Airasca',
#  649: 'Turin',
#  650: 'Turin',
#  651: 'Turin',
#  652: 'Vercelli',
#  653: 'Rubiana',
#  654: 'Antey-saint-andr\xc3\xa9',
#  655: 'Milano',
#  656: 'Turin',
#  657: 'Busca',
#  658: 'Rubiana',
#  659: 'Turin',
#  660: 'Turin',
#  661: 'Busca',
#  662: 'Turin',
#  663: 'Turin',
#  664: 'Turin',
#  665: 'Turin',
#  666: 'Rubiana',
#  667: 'Airasca',
#  668: 'Turin',
#  669: 'Turin',
#  670: 'Ghemme',
#  671: 'Rivoli',
#  672: 'Turin',
#  673: 'Turin',
#  674: 'Turin',
#  675: 'Turin',
#  676: 'Turin',
#  677: 'Turin',
#  678: 'Genova',
#  679: 'Milan',
#  680: 'Turin',
#  681: 'Turin',
#  682: 'Naples',
#  683: 'Turin',
#  684: 'Borgo Vercelli',
#  685: nan,
#  686: 'Turin',
#  687: 'Turin',
#  688: 'Turin',
#  689: 'Busca',
#  690: 'Turin',
#  691: 'Busca',
#  692: 'Asti',
#  693: 'Turin',
#  694: 'Turin',
#  695: 'Rubiana',
#  696: 'Montichiari',
#  697: 'Turin',
#  698: 'Turin',
#  699: 'Turin',
#  700: 'Turin',
#  701: 'Turin',
#  702: 'Turin',
#  703: 'San Salvatore Monferrato',
#  704: 'Turin',
#  705: 'Turin',
#  706: 'Collegno',
#  707: 'Bruino',
#  708: 'Turin',
#  709: 'Turin',
#  710: 'Turin',
#  711: 'Turin',
#  712: 'Turin',
#  713: 'Turin',
#  714: 'Piscina',
#  715: 'Turin',
#  716: 'Turin',
#  717: 'Turin',
#  718: 'Turin',
#  719: 'Turin',
#  720: 'Turin',
#  721: 'Turin',
#  722: 'Cusano Milanino',
#  723: 'Turin',
#  724: 'Turin',
#  725: 'Turin',
#  726: 'Turin',
#  727: 'Turin',
#  728: 'Turin',
#  729: 'Luserna San Giovanni',
#  730: 'Albignasego',
#  731: 'Turin',
#  732: 'Turin',
#  733: 'Turin',
#  734: 'Turin',
#  735: 'Turin',
#  736: 'Turin',
#  737: 'Turin',
#  738: 'Turin',
#  739: 'Turin',
#  740: 'Turin',
#  741: 'Turin',
#  742: 'Collegno',
#  743: 'Turin',
#  744: 'Turin',
#  745: 'Turin',
#  746: 'Turin',
#  747: 'Turin',
#  748: 'Turin',
#  749: 'Turin',
#  750: 'Turin',
#  751: 'Turin',
#  752: 'Collegno',
#  753: 'Turin',
#  754: 'Turin',
#  755: 'Turin',
#  756: 'Turin',
#  757: 'Turin',
#  758: 'Turin',
#  759: 'Turin',
#  760: 'Turin',
#  761: 'Turin',
#  762: 'Turin',
#  763: 'Rome',
#  764: 'Turin',
#  765: 'Turin',
#  766: 'Turin',
#  767: 'Turin',
#  768: 'Turin',
#  769: 'Turin',
#  770: 'Turin',
#  771: 'Turin',
#  772: 'Turin',
#  773: 'Turin',
#  774: 'Turin',
#  775: 'Turin',
#  776: 'Turin',
#  777: 'Turin',
#  778: 'Turin',
#  779: 'Turin',
#  780: "Villafranca D'asti",
#  781: 'Turin',
#  782: 'Turin',
#  783: 'Turin',
#  784: 'Turin',
#  785: 'Turin',
#  786: 'Turin',
#  787: 'Turin',
#  788: 'La Magdeleine',
#  789: 'Turin',
#  790: 'Turin',
#  791: 'Turin',
#  792: 'Turin',
#  793: 'Rubiana',
#  794: 'Turin',
#  795: 'Turin',
#  796: 'Turin',
#  797: 'Turin',
#  798: 'Turin',
#  799: 'Turin',
#  800: 'Turin',
#  801: 'Turin',
#  802: 'Milan',
#  803: 'Turin',
#  804: 'Turin',
#  805: 'Turin',
#  806: 'Turin',
#  807: 'Brusasco',
#  808: 'Turin',
#  809: 'Turin',
#  810: 'Turin',
#  811: 'Turin',
#  812: 'Turin',
#  813: 'Asti',
#  814: 'Biella',
#  815: 'Turin',
#  816: 'Almese',
#  817: 'Turin',
#  818: 'Niella Tanaro',
#  819: 'Sommariva Perno',
#  820: 'Turin',
#  821: 'Gerbido',
#  822: 'Turin',
#  823: 'Turin',
#  824: 'Turin',
#  825: 'Turin',
#  826: 'Collegno',
#  827: nan,
#  828: 'Turin',
#  829: 'Turin',
#  830: 'Bene Vagienna',
#  831: 'Nichelino',
#  832: 'Turin',
#  833: 'Rubiana',
#  834: 'Turin',
#  835: 'Almese',
#  836: 'Rubiana',
#  837: 'Turin',
#  838: 'Turin',
#  839: 'Sommariva Perno',
#  840: 'Turin',
#  841: 'Cinisello Balsamo',
#  842: 'Agli\xc3\xa8',
#  843: 'Turin',
#  844: 'Turin',
#  845: 'Turin',
#  846: 'Turin',
#  847: 'Turin',
#  848: 'Turin',
#  849: 'Turin',
#  850: 'Turin',
#  851: 'Turin',
#  852: 'Turin',
#  853: 'Turin',
#  854: 'Rubiana',
#  855: 'Turin',
#  856: 'Rivoli',
#  857: 'Salassa',
#  858: 'Turin',
#  859: 'Turin',
#  860: 'Bardonecchia',
#  861: 'Turin',
#  862: 'Turin',
#  863: 'Aramengo',
#  864: 'Turin',
#  865: 'Turin',
#  866: 'Turin',
#  867: 'Turin',
#  868: 'Cravanzana',
#  869: 'Turin',
#  870: 'Turin',
#  871: 'Turin',
#  872: 'Turin',
#  873: 'Turin',
#  874: 'Imperia',
#  875: 'Imperia',
#  876: 'Cumiana',
#  877: 'Turin',
#  878: 'Turin',
#  879: 'Caluso',
#  880: nan,
#  881: 'Imperia',
#  882: 'Novara',
#  883: 'Grugliasco',
#  884: 'Roccabruna',
#  885: 'Turin',
#  886: 'Turin',
#  887: 'Turin',
#  888: 'Turin',
#  889: 'Turin',
#  890: 'Turin',
#  891: 'Turin',
#  892: 'Varallo Pombia',
#  893: 'Asti',
#  894: 'Turin',
#  895: 'Turin',
#  896: 'Imperia',
#  897: 'Turin',
#  898: 'Imperia',
#  899: 'Imperia',
#  900: 'Turin',
#  901: 'Santena',
#  902: 'Nichelino',
#  903: 'Turin',
#  904: 'Turin',
#  905: 'Turin',
#  906: 'Nichelino',
#  907: 'Turin',
#  908: 'Turin',
#  909: 'Cagnes-sur-mer',
#  910: 'Turin',
#  911: 'Turin',
#  912: 'Turin',
#  913: 'San Salvatore Monferrato',
#  914: 'Airasca',
#  915: 'San Salvatore Monferrato',
#  916: 'Turin',
#  917: 'Turin',
#  918: 'Turin',
#  919: 'Asti',
#  920: 'Turin',
#  921: 'Turin',
#  922: 'Turin',
#  923: 'Turin',
#  924: 'Sangano',
#  925: 'Turin',
#  926: 'Rocca Canavese',
#  927: 'Turin',
#  928: 'Turin',
#  929: 'Turin',
#  930: 'Bruino',
#  931: 'Moncalieri',
#  932: 'Turin',
#  933: 'Turin',
#  934: 'Turin',
#  935: 'Turin',
#  936: 'Turin',
#  937: 'Turin',
#  938: 'Turin',
#  939: 'Turin',
#  940: 'Alba',
#  941: 'Turin',
#  942: 'Turin',
#  943: 'Nichelino',
#  944: 'Nichelino',
#  945: 'Turin',
#  946: 'Turin',
#  947: 'Alba',
#  948: 'Magliano Alpi',
#  949: 'Turin',
#  950: 'Nichelino',
#  951: 'Turin',
#  952: 'Turin',
#  953: 'Turin',
#  954: 'Andezeno',
#  955: 'Turin',
#  956: 'Villastellone',
#  957: 'Turin',
#  958: 'Turin',
#  959: 'Turin',
#  960: 'Turin',
#  961: 'Andezeno',
#  962: 'Turin',
#  963: 'Turin',
#  964: 'Turin',
#  965: 'Turin',
#  966: 'Turin',
#  967: 'Poggio Rusco',
#  968: 'Bardonecchia',
#  969: 'Turin',
#  970: 'Turin',
#  971: 'Turin',
#  972: 'Barge',
#  973: 'Turin',
#  974: 'Turin',
#  975: 'Turin',
#  976: 'Forno Canavese',
#  977: 'Forno Canavese',
#  978: 'Novara',
#  979: 'Turin',
#  980: 'Turin',
#  981: 'Caluso',
#  982: 'Turin',
#  983: 'Grugliasco',
#  984: 'Bardonecchia',
#  985: 'Fossano',
#  986: 'Pinerolo',
#  987: 'Borgaro Torinese',
#  988: 'Turin',
#  989: 'Cocconato',
#  990: 'Trofarello',
#  991: 'Ala Di Stura',
#  992: 'Turin',
#  993: 'Turin',
#  994: 'Turin',
#  995: 'Turin',
#  996: 'Turin',
#  997: 'Vercelli',
#  998: 'Turin',
#  999: 'Vetulonia',
#  ...}

# %%
s.value_counts()
# Out:
# Turin                       121227
# Rubiana                       3115
# Rivoli                        2752
# Almese                        2497
# Asti                          2398
# Novara                        2099
# Milan                         1699
# Cuneo                         1666
# Grugliasco                    1285
# Alessandria                   1260
# Genova                        1225
# Arignano                      1065
# Collegno                      1017
# Nichelino                      972
# Bruino                         918
# Cocconato                      887
# Moncalieri                     865
# Caluso                         846
# Andezeno                       787
# Biella                         779
# Marentino                      736
# Rome                           722
# Fossano                        681
# Bardonecchia                   668
# Alba                           599
# Riva Presso Chieri             564
# Avigliana                      558
# Vercelli                       547
# Aramengo                       490
# Chivasso                       465
#                              ...
# Bacau                            1
# Noyarey                          1
# Entremont-le-vieux               1
# Cison Di Valmarino               1
# Grone                            1
# Ravina                           1
# Buzau                            1
# Isola Del Piano                  1
# Umbertide                        1
# La Bouilladisse                  1
# Moconesi                         1
# Ljubljana                        1
# Storo                            1
# Sillano                          1
# Settimo Vittone                  1
# Olbia                            1
# Poviglio                         1
# Borghetto Santo Spirito          1
# Zola Predosa                     1
# Villafranca In Lunigiana         1
# Valeggio Sul Mincio              1
# Barbing                          1
# Carcare                          1
# Vergiate                         1
# Occhieppo Inferiore              1
# Marone                           1
# Varna                            1
# Dego                             1
# Istrana                          1
# Gdansk                           1
# Name: CLIENT_CITY, Length: 2039, dtype: int64

# %%
sorted([1,5,2,6,])
sorted(pd.Series([1,5,2,6]))
# Out:
# [1, 2, 5, 6]

# %%
# Since there are NULL Values we can not apply a SORT!
sorted(s)
# Out:
# [nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  ...]

# %%
#s.fillna('AAAA', inplace=True)
s.dropna(inplace=True)
s
# Out:
# 0          Bardonecchia
# 1                 Turin
# 2          Bardonecchia
# 3          Bardonecchia
# 4          Bardonecchia
# 5          Bardonecchia
# 6          Bardonecchia
# 7                 Turin
# 8              Aramengo
# 9                 Turin
# 10                Turin
# 11                Turin
# 12                Turin
# 13                Turin
# 14              Imperia
# 15                Turin
# 16              Imperia
# 17               Almese
# 18               Almese
# 19                Turin
# 20              Bibiana
# 21         Bardonecchia
# 22         Bardonecchia
# 23                Turin
# 24                 Asti
# 25                Turin
# 26                Turin
# 27                Turin
# 28                 Asti
# 29                Turin
#               ...
# 199112            Turin
# 199113            Turin
# 199114            Turin
# 199115            Turin
# 199116    Bene Vagienna
# 199117            Turin
# 199118            Turin
# 199119            Turin
# 199120            Turin
# 199121            Turin
# 199122            Turin
# 199123            Turin
# 199124          Bangkok
# 199125            Turin
# 199126           Novara
# 199127            Turin
# 199128            Turin
# 199129            Turin
# 199130           Almese
# 199132           Rivoli
# 199133           Rivoli
# 199135           Almese
# 199136           Rivoli
# 199137        Scalenghe
# 199138            Turin
# 199139       Pettenasco
# 199140         Florence
# 199141            Turin
# 199142            Turin
# 199143            Turin
# Name: CLIENT_CITY, Length: 195966, dtype: object

# %%
sorted(s)
# Out:
# ['Abakan',
#  'Abano Terme',
#  'Abano Terme',
#  'Abbadia Lariana',
#  'Abbadia San Salvatore',
#  'Abbiategrasso',
#  'Abbiategrasso',
#  'Abbiategrasso',
#  'Abetone',
#  'Acerra',
#  'Acerra',
#  'Acerra',
#  'Acerra',
#  'Acerra',
#  'Acquafredda',
#  'Acqualagna',
#  'Acquanegra Sul Chiese',
#  'Acquanegra Sul Chiese',
#  'Acqui Terme',
#  'Acqui Terme',
#  'Acqui Terme',
#  'Acqui Terme',
#  'Acqui Terme',
#  'Acqui Terme',
#  'Acqui Terme',
#  'Acqui Terme',
#  'Acqui Terme',
#  'Acqui Terme',
#  'Acqui Terme',
#  'Acqui Terme',
#  'Acqui Terme',
#  'Acqui Terme',
#  'Acqui Terme',
#  'Acqui Terme',
#  'Acqui Terme',
#  'Acqui Terme',
#  'Acqui Terme',
#  'Acqui Terme',
#  'Acqui Terme',
#  'Acqui Terme',
#  'Acqui Terme',
#  'Acqui Terme',
#  'Acqui Terme',
#  'Acqui Terme',
#  'Acqui Terme',
#  'Acqui Terme',
#  'Acqui Terme',
#  'Acqui Terme',
#  'Acqui Terme',
#  'Acqui Terme',
#  'Acqui Terme',
#  'Acqui Terme',
#  'Acqui Terme',
#  'Acqui Terme',
#  'Acqui Terme',
#  'Acqui Terme',
#  'Acqui Terme',
#  'Acqui Terme',
#  'Acqui Terme',
#  'Acqui Terme',
#  'Acqui Terme',
#  'Acqui Terme',
#  'Acqui Terme',
#  'Acqui Terme',
#  'Acqui Terme',
#  'Acqui Terme',
#  'Acqui Terme',
#  'Acqui Terme',
#  'Acqui Terme',
#  'Acqui Terme',
#  'Acqui Terme',
#  'Acqui Terme',
#  'Acqui Terme',
#  'Acqui Terme',
#  'Acqui Terme',
#  'Acqui Terme',
#  'Acqui Terme',
#  'Acqui Terme',
#  'Acqui Terme',
#  'Acqui Terme',
#  'Acqui Terme',
#  'Acqui Terme',
#  'Acqui Terme',
#  'Acqui Terme',
#  'Acqui Terme',
#  'Acqui Terme',
#  'Acqui Terme',
#  'Acqui Terme',
#  'Acqui Terme',
#  'Acqui Terme',
#  'Acqui Terme',
#  'Acqui Terme',
#  'Acqui Terme',
#  'Acqui Terme',
#  'Acqui Terme',
#  'Acqui Terme',
#  'Acqui Terme',
#  'Acqui Terme',
#  'Acqui Terme',
#  'Acqui Terme',
#  'Acqui Terme',
#  'Acqui Terme',
#  'Acqui Terme',
#  'Acqui Terme',
#  'Acqui Terme',
#  'Acqui Terme',
#  'Acqui Terme',
#  'Acqui Terme',
#  'Acqui Terme',
#  'Acqui Terme',
#  'Acqui Terme',
#  'Acqui Terme',
#  'Acqui Terme',
#  'Acqui Terme',
#  'Acqui Terme',
#  'Acqui Terme',
#  'Acqui Terme',
#  'Acqui Terme',
#  'Acqui Terme',
#  'Acqui Terme',
#  'Acqui Terme',
#  'Acqui Terme',
#  'Acqui Terme',
#  'Acqui Terme',
#  'Acqui Terme',
#  'Acqui Terme',
#  'Acqui Terme',
#  'Acqui Terme',
#  'Acqui Terme',
#  'Acqui Terme',
#  'Acuto',
#  'Acuto',
#  'Acuto',
#  'Acuto',
#  'Acuto',
#  'Acuto',
#  'Adelfia',
#  'Adelfia',
#  'Adelfia',
#  'Adelfia',
#  'Adro',
#  'Adro',
#  'Affi',
#  'Afragola',
#  'Agliano',
#  'Agliano',
#  'Agliano',
#  'Agliano',
#  'Agliano',
#  'Agliano',
#  'Agliano',
#  'Agliano',
#  'Agliano',
#  'Agliano',
#  'Agliano',
#  'Agliano',
#  'Agliano',
#  'Agliano',
#  'Agliano',
#  'Agliano',
#  'Agliano',
#  'Agliano',
#  'Agliano',
#  'Agliano',
#  'Agliano',
#  'Agliano',
#  'Agliano',
#  'Agliano',
#  'Agliano',
#  'Agliano',
#  'Agliano',
#  'Agliano',
#  'Agliano',
#  'Agliano',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agli\xc3\xa8',
#  'Agognate',
#  'Agognate',
#  'Agognate',
#  'Agognate',
#  'Agognate',
#  'Agognate',
#  'Agognate',
#  'Agognate',
#  'Agognate',
#  'Agognate',
#  'Agognate',
#  'Agognate',
#  'Agognate',
#  'Agognate',
#  'Agognate',
#  'Agognate',
#  'Agognate',
#  'Agognate',
#  'Agognate',
#  'Agognate',
#  'Agognate',
#  'Agognate',
#  'Agognate',
#  'Agognate',
#  'Agognate',
#  'Agordo',
#  'Agrate',
#  'Agrate Brianza',
#  'Agrate Brianza',
#  'Agrate Brianza',
#  'Agrate Brianza',
#  'Agrate Brianza',
#  'Agrate Brianza',
#  'Agrate Brianza',
#  'Agrate Brianza',
#  'Agrate Brianza',
#  'Agrate Brianza',
#  'Agrate Brianza',
#  'Agrigento',
#  'Agrigento',
#  'Agrigento',
#  'Agugliano',
#  'Agugliano',
#  'Agugliano',
#  'Agugliaro',
#  'Agugliaro',
#  'Aiello Del Friuli',
#  'Aiello Del Friuli',
#  'Aiguebelette',
#  'Aillon-le-jeune',
#  'Ailoche',
#  'Ailoche',
#  'Ailoche',
#  'Ailoche',
#  'Ailoche',
#  'Ailoche',
#  'Ailoche',
#  'Ailoche',
#  'Ailoche',
#  'Ailoche',
#  'Ailoche',
#  'Ailoche',
#  'Ailoche',
#  'Ailoche',
#  'Ailoche',
#  'Ailoche',
#  'Ailoche',
#  'Ailoche',
#  'Ailoche',
#  'Ailoche',
#  'Ailoche',
#  'Ailoche',
#  'Ailoche',
#  'Ailoche',
#  'Aime',
#  'Aime',
#  'Aime',
#  'Aime',
#  'Airasca',
#  'Airasca',
#  'Airasca',
#  'Airasca',
#  'Airasca',
#  'Airasca',
#  'Airasca',
#  'Airasca',
#  'Airasca',
#  'Airasca',
#  'Airasca',
#  'Airasca',
#  'Airasca',
#  'Airasca',
#  'Airasca',
#  'Airasca',
#  'Airasca',
#  'Airasca',
#  'Airasca',
#  'Airasca',
#  'Airasca',
#  'Airasca',
#  'Airasca',
#  'Airasca',
#  'Airasca',
#  'Airasca',
#  'Airasca',
#  'Airasca',
#  'Airasca',
#  'Airasca',
#  'Airasca',
#  'Airasca',
#  'Airasca',
#  'Airasca',
#  'Airasca',
#  'Airasca',
#  'Airasca',
#  'Airasca',
#  'Airasca',
#  'Airasca',
#  'Airasca',
#  'Airasca',
#  'Airasca',
#  'Airasca',
#  'Airasca',
#  'Airasca',
#  'Airasca',
#  'Airasca',
#  'Airasca',
#  'Airasca',
#  'Airasca',
#  'Airasca',
#  'Airasca',
#  'Airasca',
#  'Airasca',
#  'Airasca',
#  'Airasca',
#  'Airasca',
#  'Airasca',
#  'Airasca',
#  'Airasca',
#  'Airasca',
#  'Airasca',
#  'Airasca',
#  'Airasca',
#  'Airasca',
#  'Airasca',
#  'Airasca',
#  'Airasca',
#  'Airasca',
#  'Airasca',
#  'Airasca',
#  'Airasca',
#  'Airasca',
#  'Airasca',
#  'Airasca',
#  'Airasca',
#  'Airasca',
#  'Airasca',
#  'Airasca',
#  'Airasca',
#  'Airasca',
#  'Airasca',
#  'Airasca',
#  'Airasca',
#  'Airasca',
#  'Airasca',
#  'Airasca',
#  'Airasca',
#  'Airasca',
#  'Airasca',
#  'Airasca',
#  'Airasca',
#  'Airasca',
#  'Airasca',
#  'Airasca',
#  'Airasca',
#  'Airasca',
#  'Airasca',
#  'Airasca',
#  'Airasca',
#  'Airasca',
#  'Airasca',
#  'Airasca',
#  'Airasca',
#  'Airasca',
#  'Airasca',
#  'Airasca',
#  'Airasca',
#  'Airasca',
#  'Airasca',
#  'Airasca',
#  'Airasca',
#  'Airasca',
#  'Airasca',
#  'Airasca',
#  'Airasca',
#  'Airasca',
#  'Airasca',
#  'Airasca',
#  'Airasca',
#  'Airasca',
#  'Airasca',
#  'Airasca',
#  'Airasca',
#  'Airasca',
#  'Airasca',
#  'Airasca',
#  'Airasca',
#  'Airasca',
#  'Airasca',
#  'Airasca',
#  'Airasca',
#  'Airasca',
#  'Airasca',
#  'Airasca',
#  'Airasca',
#  'Airasca',
#  'Airasca',
#  'Airasca',
#  'Airasca',
#  'Airasca',
#  'Airasca',
#  'Airasca',
#  'Airasca',
#  'Airasca',
#  'Airasca',
#  'Airasca',
#  'Airasca',
#  'Airasca',
#  'Airasca',
#  'Airasca',
#  'Airasca',
#  'Airasca',
#  'Airasca',
#  'Airasca',
#  'Airuno',
#  'Airuno',
#  'Aiton',
#  'Aiton',
#  'Aix-en-provence',
#  'Aix-en-provence',
#  'Aix-les-bains',
#  'Aix-les-bains',
#  'Ajaccio',
#  'Ajaccio',
#  'Ajaccio',
#  'Ajaccio',
#  'Ajaccio',
#  'Ajaccio',
#  'Ajaccio',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  'Ala Di Stura',
#  ...]

# %%
s = pd.read_csv('dataset/users.csv',
                index_col='NAME',
                squeeze=True)

# %%
s.head()
# Out:
# NAME
# Abbondanzio    1
# Abdone         2
# Abele          3
# Abibo          4
# Abramo         5
# Name: ID, dtype: int64

# %%
s['Abramo']
# Out:
# 5

# %%
s['Abbondanzio':'Abele']
# Out:
# NAME
# Abbondanzio    1
# Abdone         2
# Abele          3
# Name: ID, dtype: int64

# %%
s[['Carlo', 'Not Found']]
# Out:
# NAME
# Carlo        165.0
# Not Found      NaN
# Name: ID, dtype: float64

# %%
s = pd.read_csv('dataset/users.csv',
                index_col='ID',
                squeeze=True)

# %%
s.head()
# Out:
# ID
# 1    Abbondanzio
# 2         Abdone
# 3          Abele
# 4          Abibo
# 5         Abramo
# Name: NAME, dtype: object

# %%
s[1:10]
# Out:
# ID
# 2        Abdone
# 3         Abele
# 4         Abibo
# 5        Abramo
# 6        Acario
# 7       Achille
# 8      Aciscolo
# 9      Adalardo
# 10    Adalfredo
# Name: NAME, dtype: object

# %%
s[::-1]
# Out:
# ID
# 220      Cunegonda
# 219     Crocefissa
# 218      Cristiana
# 217       Costanza
# 216       Cornelia
# 215       Cordelia
# 214      Consolata
# 213        Colomba
# 212       Clorinda
# 211      Cleopatra
# 210           Cleo
# 209         Clelia
# 208          Clara
# 207         Cinzia
# 206        Celinia
# 205        Cecilia
# 204         Catena
# 203      Cassandra
# 202        Casilda
# 201         Carola
# 200        Carmela
# 199          Carla
# 198     Capitolina
# 197        Camilla
# 196      Calpurnia
# 195      Cuniberto
# 194     Cristoforo
# 193      Cristaldo
# 192    Crespignano
# 191      Crescente
#           ...
# 30       Alcibiade
# 29           Alceo
# 28         Alboino
# 27         Alberto
# 26          Albano
# 25           Alano
# 24         Aladino
# 23          Aidano
# 22         Agrippa
# 21        Agesilao
# 20          Agazio
# 19      Agamennone
# 18            Afro
# 17         Adriano
# 16          Adolfo
# 15          Adelmo
# 14          Adelfo
# 13       Adelberto
# 12            Addo
# 11        Adalrico
# 10       Adalfredo
# 9         Adalardo
# 8         Aciscolo
# 7          Achille
# 6           Acario
# 5           Abramo
# 4            Abibo
# 3            Abele
# 2           Abdone
# 1      Abbondanzio
# Name: NAME, Length: 220, dtype: object
